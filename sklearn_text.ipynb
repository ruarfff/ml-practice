# %% [markdown]
# <a href="https://colab.research.google.com/github/ruarfff/ml-practice/blob/main/sklearn_text.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Following the [Working With Text Data Tutorial](https://scikit-learn.org/stable/tutorial/text_analytics/working_with_text_data.html) for [scikit-learn](https://scikit-learn.org/stable/).

# %%
# !pip install -U scikit-learn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (1.0.2)
# Collecting scikit-learn
#   Downloading scikit_learn-1.2.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.7 MB)
#      |████████████████████████████████| 9.7 MB 13.5 MB/s
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.8/dist-packages (from scikit-learn) (1.21.6)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.8/dist-packages (from scikit-learn) (1.7.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn) (3.1.0)
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.0.2
#     Uninstalling scikit-learn-1.0.2:
#       Successfully uninstalled scikit-learn-1.0.2
# Successfully installed scikit-learn-1.2.0

# %%
# Check installation
# !python -m pip show scikit-learn 
# !python -c "import sklearn; sklearn.show_versions()"
# Out:
# Name: scikit-learn
# Version: 1.2.0
# Summary: A set of python modules for machine learning and data mining
# Home-page: http://scikit-learn.org
# Author: None
# Author-email: None
# License: new BSD
# Location: /usr/local/lib/python3.8/dist-packages
# Requires: scipy, threadpoolctl, joblib, numpy
# Required-by: yellowbrick, sklearn-pandas, qudida, mlxtend, lightgbm, librosa, imbalanced-learn, fastai
#
# System:
#     python: 3.8.16 (default, Dec  7 2022, 01:12:13)  [GCC 7.5.0]
# executable: /usr/bin/python3
#    machine: Linux-5.10.133+-x86_64-with-glibc2.27
#
# Python dependencies:
#       sklearn: 1.2.0
#           pip: 21.1.3
#    setuptools: 57.4.0
#         numpy: 1.21.6
#         scipy: 1.7.3
#        Cython: 0.29.32
#        pandas: 1.3.5
#    matplotlib: 3.2.2
#        joblib: 1.2.0
# threadpoolctl: 3.1.0
#
# Built with OpenMP: True
#
# threadpoolctl info:
#        user_api: openmp
#    internal_api: openmp
#          prefix: libgomp
#        filepath: /usr/local/lib/python3.8/dist-packages/scikit_learn.libs/libgomp-a34b3233.so.1.0.0
#         version: None
#     num_threads: 2
#
#        user_api: blas
#    internal_api: openblas
#          prefix: libopenblas
#        filepath: /usr/local/lib/python3.8/dist-packages/numpy.libs/libopenblasp-r0-2d23e62b.3.17.so
#         version: 0.3.17
# threading_layer: pthreads
#    architecture: Zen
#     num_threads: 2
#
#        user_api: blas
#    internal_api: openblas
#          prefix: libopenblas
#        filepath: /usr/local/lib/python3.8/dist-packages/scipy.libs/libopenblasp-r0-8b9e111f.3.17.so
#         version: 0.3.17
# threading_layer: pthreads
#    architecture: Zen
#     num_threads: 2

# %% [markdown]
# Fetch data for the tutorial.

# %%
# simple python script to collect text paragraphs from various languages on the
# same topic namely the Wikipedia encyclopedia itself

import os
from urllib.request import Request, build_opener

import lxml.html
from lxml.etree import ElementTree
import numpy as np

import codecs

pages = {
    'ar': 'http://ar.wikipedia.org/wiki/%D9%88%D9%8A%D9%83%D9%8A%D8%A8%D9%8A%D8%AF%D9%8A%D8%A7',   # noqa: E501
    'de': 'http://de.wikipedia.org/wiki/Wikipedia',
    'en': 'https://en.wikipedia.org/wiki/Wikipedia',
    'es': 'http://es.wikipedia.org/wiki/Wikipedia',
    'fr': 'http://fr.wikipedia.org/wiki/Wikip%C3%A9dia',
    'it': 'http://it.wikipedia.org/wiki/Wikipedia',
    'ja': 'http://ja.wikipedia.org/wiki/Wikipedia',
    'nl': 'http://nl.wikipedia.org/wiki/Wikipedia',
    'pl': 'http://pl.wikipedia.org/wiki/Wikipedia',
    'pt': 'http://pt.wikipedia.org/wiki/Wikip%C3%A9dia',
    'ru': 'http://ru.wikipedia.org/wiki/%D0%92%D0%B8%D0%BA%D0%B8%D0%BF%D0%B5%D0%B4%D0%B8%D1%8F',  # noqa: E501
#    u'zh': u'http://zh.wikipedia.org/wiki/Wikipedia',
}

html_folder = 'html'
text_folder = 'paragraphs'
short_text_folder = 'short_paragraphs'
n_words_per_short_text = 5


if not os.path.exists(html_folder):
    os.makedirs(html_folder)

for lang, page in pages.items():

    text_lang_folder = os.path.join(text_folder, lang)
    if not os.path.exists(text_lang_folder):
        os.makedirs(text_lang_folder)

    short_text_lang_folder = os.path.join(short_text_folder, lang)
    if not os.path.exists(short_text_lang_folder):
        os.makedirs(short_text_lang_folder)

    opener = build_opener()
    html_filename = os.path.join(html_folder, lang + '.html')
    if not os.path.exists(html_filename):
        print("Downloading %s" % page)
        request = Request(page)
        # change the User Agent to avoid being blocked by Wikipedia
        # downloading a couple of articles should not be considered abusive
        request.add_header('User-Agent', 'OpenAnything/1.0')
        html_content = opener.open(request).read()
        with open(html_filename, 'wb') as f:
            f.write(html_content)

    # decode the payload explicitly as UTF-8 since lxml is confused for some
    # reason
    with codecs.open(html_filename,'r','utf-8') as html_file:
        html_content = html_file.read()
    tree = ElementTree(lxml.html.document_fromstring(html_content))
    i = 0
    j = 0
    for p in tree.findall('//p'):
        content = p.text_content()
        if len(content) < 100:
            # skip paragraphs that are too short - probably too noisy and not
            # representative of the actual language
            continue

        text_filename = os.path.join(text_lang_folder,
                                     '%s_%04d.txt' % (lang, i))
        print("Writing %s" % text_filename)
        with open(text_filename, 'wb') as f:
            f.write(content.encode('utf-8', 'ignore'))
        i += 1

        # split the paragraph into fake smaller paragraphs to make the
        # problem harder e.g. more similar to tweets
        if lang in ('zh', 'ja'):
        # FIXME: whitespace tokenizing does not work on chinese and japanese
            continue
        words = content.split()
        n_groups = len(words) / n_words_per_short_text
        if n_groups < 1:
            continue
        groups = np.array_split(words, n_groups)

        for group in groups:
            small_content = " ".join(group)

            short_text_filename = os.path.join(short_text_lang_folder,
                                               '%s_%04d.txt' % (lang, j))
            print("Writing %s" % short_text_filename)
            with open(short_text_filename, 'wb') as f:
                f.write(small_content.encode('utf-8', 'ignore'))
            j += 1
            if j >= 1000:
                break
# Out:
# Streaming output truncated to the last 5000 lines.
# Writing paragraphs/it/it_0005.txt
# Writing short_paragraphs/it/it_0044.txt
# Writing short_paragraphs/it/it_0045.txt
# Writing short_paragraphs/it/it_0046.txt
# Writing short_paragraphs/it/it_0047.txt
# Writing paragraphs/it/it_0006.txt
# Writing short_paragraphs/it/it_0048.txt
# Writing short_paragraphs/it/it_0049.txt
# Writing short_paragraphs/it/it_0050.txt
# Writing short_paragraphs/it/it_0051.txt
# Writing short_paragraphs/it/it_0052.txt
# Writing short_paragraphs/it/it_0053.txt
# Writing short_paragraphs/it/it_0054.txt
# Writing short_paragraphs/it/it_0055.txt
# Writing short_paragraphs/it/it_0056.txt
# Writing short_paragraphs/it/it_0057.txt
# Writing paragraphs/it/it_0007.txt
# Writing short_paragraphs/it/it_0058.txt
# Writing short_paragraphs/it/it_0059.txt
# Writing short_paragraphs/it/it_0060.txt
# Writing short_paragraphs/it/it_0061.txt
# Writing short_paragraphs/it/it_0062.txt
# Writing short_paragraphs/it/it_0063.txt
# Writing short_paragraphs/it/it_0064.txt
# Writing short_paragraphs/it/it_0065.txt
# Writing short_paragraphs/it/it_0066.txt
# Writing short_paragraphs/it/it_0067.txt
# Writing short_paragraphs/it/it_0068.txt
# Writing short_paragraphs/it/it_0069.txt
# Writing short_paragraphs/it/it_0070.txt
# Writing short_paragraphs/it/it_0071.txt
# Writing short_paragraphs/it/it_0072.txt
# Writing short_paragraphs/it/it_0073.txt
# Writing short_paragraphs/it/it_0074.txt
# Writing short_paragraphs/it/it_0075.txt
# Writing short_paragraphs/it/it_0076.txt
# Writing short_paragraphs/it/it_0077.txt
# Writing short_paragraphs/it/it_0078.txt
# Writing paragraphs/it/it_0008.txt
# Writing short_paragraphs/it/it_0079.txt
# Writing short_paragraphs/it/it_0080.txt
# Writing short_paragraphs/it/it_0081.txt
# Writing short_paragraphs/it/it_0082.txt
# Writing short_paragraphs/it/it_0083.txt
# Writing short_paragraphs/it/it_0084.txt
# Writing short_paragraphs/it/it_0085.txt
# Writing short_paragraphs/it/it_0086.txt
# Writing short_paragraphs/it/it_0087.txt
# Writing short_paragraphs/it/it_0088.txt
# Writing short_paragraphs/it/it_0089.txt
# Writing short_paragraphs/it/it_0090.txt
# Writing short_paragraphs/it/it_0091.txt
# Writing short_paragraphs/it/it_0092.txt
# Writing short_paragraphs/it/it_0093.txt
# Writing short_paragraphs/it/it_0094.txt
# Writing short_paragraphs/it/it_0095.txt
# Writing short_paragraphs/it/it_0096.txt
# Writing short_paragraphs/it/it_0097.txt
# Writing paragraphs/it/it_0009.txt
# Writing short_paragraphs/it/it_0098.txt
# Writing short_paragraphs/it/it_0099.txt
# Writing short_paragraphs/it/it_0100.txt
# Writing short_paragraphs/it/it_0101.txt
# Writing short_paragraphs/it/it_0102.txt
# Writing short_paragraphs/it/it_0103.txt
# Writing short_paragraphs/it/it_0104.txt
# Writing short_paragraphs/it/it_0105.txt
# Writing short_paragraphs/it/it_0106.txt
# Writing short_paragraphs/it/it_0107.txt
# Writing short_paragraphs/it/it_0108.txt
# Writing short_paragraphs/it/it_0109.txt
# Writing short_paragraphs/it/it_0110.txt
# Writing short_paragraphs/it/it_0111.txt
# Writing paragraphs/it/it_0010.txt
# Writing short_paragraphs/it/it_0112.txt
# Writing short_paragraphs/it/it_0113.txt
# Writing short_paragraphs/it/it_0114.txt
# Writing short_paragraphs/it/it_0115.txt
# Writing short_paragraphs/it/it_0116.txt
# Writing short_paragraphs/it/it_0117.txt
# Writing short_paragraphs/it/it_0118.txt
# Writing short_paragraphs/it/it_0119.txt
# Writing paragraphs/it/it_0011.txt
# Writing short_paragraphs/it/it_0120.txt
# Writing short_paragraphs/it/it_0121.txt
# Writing short_paragraphs/it/it_0122.txt
# Writing short_paragraphs/it/it_0123.txt
# Writing short_paragraphs/it/it_0124.txt
# Writing short_paragraphs/it/it_0125.txt
# Writing short_paragraphs/it/it_0126.txt
# Writing short_paragraphs/it/it_0127.txt
# Writing short_paragraphs/it/it_0128.txt
# Writing short_paragraphs/it/it_0129.txt
# Writing short_paragraphs/it/it_0130.txt
# Writing short_paragraphs/it/it_0131.txt
# Writing short_paragraphs/it/it_0132.txt
# Writing short_paragraphs/it/it_0133.txt
# Writing short_paragraphs/it/it_0134.txt
# Writing short_paragraphs/it/it_0135.txt
# Writing short_paragraphs/it/it_0136.txt
# Writing short_paragraphs/it/it_0137.txt
# Writing short_paragraphs/it/it_0138.txt
# Writing short_paragraphs/it/it_0139.txt
# Writing short_paragraphs/it/it_0140.txt
# Writing short_paragraphs/it/it_0141.txt
# Writing paragraphs/it/it_0012.txt
# Writing short_paragraphs/it/it_0142.txt
# Writing short_paragraphs/it/it_0143.txt
# Writing short_paragraphs/it/it_0144.txt
# Writing short_paragraphs/it/it_0145.txt
# Writing short_paragraphs/it/it_0146.txt
# Writing paragraphs/it/it_0013.txt
# Writing short_paragraphs/it/it_0147.txt
# Writing short_paragraphs/it/it_0148.txt
# Writing short_paragraphs/it/it_0149.txt
# Writing short_paragraphs/it/it_0150.txt
# Writing short_paragraphs/it/it_0151.txt
# Writing short_paragraphs/it/it_0152.txt
# Writing short_paragraphs/it/it_0153.txt
# Writing short_paragraphs/it/it_0154.txt
# Writing short_paragraphs/it/it_0155.txt
# Writing short_paragraphs/it/it_0156.txt
# Writing paragraphs/it/it_0014.txt
# Writing short_paragraphs/it/it_0157.txt
# Writing short_paragraphs/it/it_0158.txt
# Writing short_paragraphs/it/it_0159.txt
# Writing short_paragraphs/it/it_0160.txt
# Writing paragraphs/it/it_0015.txt
# Writing short_paragraphs/it/it_0161.txt
# Writing short_paragraphs/it/it_0162.txt
# Writing short_paragraphs/it/it_0163.txt
# Writing short_paragraphs/it/it_0164.txt
# Writing short_paragraphs/it/it_0165.txt
# Writing short_paragraphs/it/it_0166.txt
# Writing short_paragraphs/it/it_0167.txt
# Writing short_paragraphs/it/it_0168.txt
# Writing short_paragraphs/it/it_0169.txt
# Writing short_paragraphs/it/it_0170.txt
# Writing short_paragraphs/it/it_0171.txt
# Writing paragraphs/it/it_0016.txt
# Writing short_paragraphs/it/it_0172.txt
# Writing short_paragraphs/it/it_0173.txt
# Writing short_paragraphs/it/it_0174.txt
# Writing short_paragraphs/it/it_0175.txt
# Writing short_paragraphs/it/it_0176.txt
# Writing short_paragraphs/it/it_0177.txt
# Writing paragraphs/it/it_0017.txt
# Writing short_paragraphs/it/it_0178.txt
# Writing short_paragraphs/it/it_0179.txt
# Writing short_paragraphs/it/it_0180.txt
# Writing short_paragraphs/it/it_0181.txt
# Writing short_paragraphs/it/it_0182.txt
# Writing short_paragraphs/it/it_0183.txt
# Writing short_paragraphs/it/it_0184.txt
# Writing short_paragraphs/it/it_0185.txt
# Writing short_paragraphs/it/it_0186.txt
# Writing short_paragraphs/it/it_0187.txt
# Writing short_paragraphs/it/it_0188.txt
# Writing short_paragraphs/it/it_0189.txt
# Writing short_paragraphs/it/it_0190.txt
# Writing short_paragraphs/it/it_0191.txt
# Writing short_paragraphs/it/it_0192.txt
# Writing short_paragraphs/it/it_0193.txt
# Writing short_paragraphs/it/it_0194.txt
# Writing paragraphs/it/it_0018.txt
# Writing short_paragraphs/it/it_0195.txt
# Writing short_paragraphs/it/it_0196.txt
# Writing short_paragraphs/it/it_0197.txt
# Writing short_paragraphs/it/it_0198.txt
# Writing short_paragraphs/it/it_0199.txt
# Writing short_paragraphs/it/it_0200.txt
# Writing short_paragraphs/it/it_0201.txt
# Writing short_paragraphs/it/it_0202.txt
# Writing short_paragraphs/it/it_0203.txt
# Writing short_paragraphs/it/it_0204.txt
# Writing short_paragraphs/it/it_0205.txt
# Writing short_paragraphs/it/it_0206.txt
# Writing short_paragraphs/it/it_0207.txt
# Writing short_paragraphs/it/it_0208.txt
# Writing short_paragraphs/it/it_0209.txt
# Writing short_paragraphs/it/it_0210.txt
# Writing short_paragraphs/it/it_0211.txt
# Writing short_paragraphs/it/it_0212.txt
# Writing short_paragraphs/it/it_0213.txt
# Writing short_paragraphs/it/it_0214.txt
# Writing short_paragraphs/it/it_0215.txt
# Writing short_paragraphs/it/it_0216.txt
# Writing short_paragraphs/it/it_0217.txt
# Writing short_paragraphs/it/it_0218.txt
# Writing paragraphs/it/it_0019.txt
# Writing short_paragraphs/it/it_0219.txt
# Writing short_paragraphs/it/it_0220.txt
# Writing short_paragraphs/it/it_0221.txt
# Writing short_paragraphs/it/it_0222.txt
# Writing short_paragraphs/it/it_0223.txt
# Writing short_paragraphs/it/it_0224.txt
# Writing short_paragraphs/it/it_0225.txt
# Writing short_paragraphs/it/it_0226.txt
# Writing short_paragraphs/it/it_0227.txt
# Writing short_paragraphs/it/it_0228.txt
# Writing short_paragraphs/it/it_0229.txt
# Writing short_paragraphs/it/it_0230.txt
# Writing short_paragraphs/it/it_0231.txt
# Writing short_paragraphs/it/it_0232.txt
# Writing short_paragraphs/it/it_0233.txt
# Writing short_paragraphs/it/it_0234.txt
# Writing short_paragraphs/it/it_0235.txt
# Writing short_paragraphs/it/it_0236.txt
# Writing paragraphs/it/it_0020.txt
# Writing short_paragraphs/it/it_0237.txt
# Writing short_paragraphs/it/it_0238.txt
# Writing short_paragraphs/it/it_0239.txt
# Writing short_paragraphs/it/it_0240.txt
# Writing short_paragraphs/it/it_0241.txt
# Writing short_paragraphs/it/it_0242.txt
# Writing short_paragraphs/it/it_0243.txt
# Writing short_paragraphs/it/it_0244.txt
# Writing short_paragraphs/it/it_0245.txt
# Writing short_paragraphs/it/it_0246.txt
# Writing short_paragraphs/it/it_0247.txt
# Writing short_paragraphs/it/it_0248.txt
# Writing short_paragraphs/it/it_0249.txt
# Writing short_paragraphs/it/it_0250.txt
# Writing short_paragraphs/it/it_0251.txt
# Writing paragraphs/it/it_0021.txt
# Writing short_paragraphs/it/it_0252.txt
# Writing short_paragraphs/it/it_0253.txt
# Writing short_paragraphs/it/it_0254.txt
# Writing short_paragraphs/it/it_0255.txt
# Writing short_paragraphs/it/it_0256.txt
# Writing short_paragraphs/it/it_0257.txt
# Writing short_paragraphs/it/it_0258.txt
# Writing short_paragraphs/it/it_0259.txt
# Writing short_paragraphs/it/it_0260.txt
# Writing short_paragraphs/it/it_0261.txt
# Writing short_paragraphs/it/it_0262.txt
# Writing short_paragraphs/it/it_0263.txt
# Writing short_paragraphs/it/it_0264.txt
# Writing short_paragraphs/it/it_0265.txt
# Writing short_paragraphs/it/it_0266.txt
# Writing short_paragraphs/it/it_0267.txt
# Writing short_paragraphs/it/it_0268.txt
# Writing short_paragraphs/it/it_0269.txt
# Writing paragraphs/it/it_0022.txt
# Writing short_paragraphs/it/it_0270.txt
# Writing short_paragraphs/it/it_0271.txt
# Writing short_paragraphs/it/it_0272.txt
# Writing short_paragraphs/it/it_0273.txt
# Writing short_paragraphs/it/it_0274.txt
# Writing short_paragraphs/it/it_0275.txt
# Writing short_paragraphs/it/it_0276.txt
# Writing short_paragraphs/it/it_0277.txt
# Writing short_paragraphs/it/it_0278.txt
# Writing short_paragraphs/it/it_0279.txt
# Writing short_paragraphs/it/it_0280.txt
# Writing short_paragraphs/it/it_0281.txt
# Writing paragraphs/it/it_0023.txt
# Writing short_paragraphs/it/it_0282.txt
# Writing short_paragraphs/it/it_0283.txt
# Writing short_paragraphs/it/it_0284.txt
# Writing short_paragraphs/it/it_0285.txt
# Writing short_paragraphs/it/it_0286.txt
# Writing short_paragraphs/it/it_0287.txt
# Writing short_paragraphs/it/it_0288.txt
# Writing short_paragraphs/it/it_0289.txt
# Writing short_paragraphs/it/it_0290.txt
# Writing short_paragraphs/it/it_0291.txt
# Writing short_paragraphs/it/it_0292.txt
# Writing short_paragraphs/it/it_0293.txt
# Writing short_paragraphs/it/it_0294.txt
# Writing short_paragraphs/it/it_0295.txt
# Writing short_paragraphs/it/it_0296.txt
# Writing short_paragraphs/it/it_0297.txt
# Writing short_paragraphs/it/it_0298.txt
# Writing short_paragraphs/it/it_0299.txt
# Writing short_paragraphs/it/it_0300.txt
# Writing short_paragraphs/it/it_0301.txt
# Writing short_paragraphs/it/it_0302.txt
# Writing short_paragraphs/it/it_0303.txt
# Writing short_paragraphs/it/it_0304.txt
# Writing short_paragraphs/it/it_0305.txt
# Writing short_paragraphs/it/it_0306.txt
# Writing short_paragraphs/it/it_0307.txt
# Writing short_paragraphs/it/it_0308.txt
# Writing short_paragraphs/it/it_0309.txt
# Writing short_paragraphs/it/it_0310.txt
# Writing paragraphs/it/it_0024.txt
# Writing short_paragraphs/it/it_0311.txt
# Writing short_paragraphs/it/it_0312.txt
# Writing short_paragraphs/it/it_0313.txt
# Writing short_paragraphs/it/it_0314.txt
# Writing short_paragraphs/it/it_0315.txt
# Writing short_paragraphs/it/it_0316.txt
# Writing short_paragraphs/it/it_0317.txt
# Writing short_paragraphs/it/it_0318.txt
# Writing short_paragraphs/it/it_0319.txt
# Writing short_paragraphs/it/it_0320.txt
# Writing short_paragraphs/it/it_0321.txt
# Writing short_paragraphs/it/it_0322.txt
# Writing short_paragraphs/it/it_0323.txt
# Writing short_paragraphs/it/it_0324.txt
# Writing short_paragraphs/it/it_0325.txt
# Writing short_paragraphs/it/it_0326.txt
# Writing short_paragraphs/it/it_0327.txt
# Writing short_paragraphs/it/it_0328.txt
# Writing short_paragraphs/it/it_0329.txt
# Writing short_paragraphs/it/it_0330.txt
# Writing short_paragraphs/it/it_0331.txt
# Writing short_paragraphs/it/it_0332.txt
# Writing short_paragraphs/it/it_0333.txt
# Writing short_paragraphs/it/it_0334.txt
# Writing short_paragraphs/it/it_0335.txt
# Writing paragraphs/it/it_0025.txt
# Writing short_paragraphs/it/it_0336.txt
# Writing short_paragraphs/it/it_0337.txt
# Writing short_paragraphs/it/it_0338.txt
# Writing short_paragraphs/it/it_0339.txt
# Writing short_paragraphs/it/it_0340.txt
# Writing short_paragraphs/it/it_0341.txt
# Writing short_paragraphs/it/it_0342.txt
# Writing short_paragraphs/it/it_0343.txt
# Writing short_paragraphs/it/it_0344.txt
# Writing short_paragraphs/it/it_0345.txt
# Writing short_paragraphs/it/it_0346.txt
# Writing short_paragraphs/it/it_0347.txt
# Writing short_paragraphs/it/it_0348.txt
# Writing short_paragraphs/it/it_0349.txt
# Writing short_paragraphs/it/it_0350.txt
# Writing short_paragraphs/it/it_0351.txt
# Writing short_paragraphs/it/it_0352.txt
# Writing short_paragraphs/it/it_0353.txt
# Writing short_paragraphs/it/it_0354.txt
# Writing short_paragraphs/it/it_0355.txt
# Writing short_paragraphs/it/it_0356.txt
# Writing short_paragraphs/it/it_0357.txt
# Writing paragraphs/it/it_0026.txt
# Writing short_paragraphs/it/it_0358.txt
# Writing short_paragraphs/it/it_0359.txt
# Writing short_paragraphs/it/it_0360.txt
# Writing short_paragraphs/it/it_0361.txt
# Writing short_paragraphs/it/it_0362.txt
# Writing short_paragraphs/it/it_0363.txt
# Writing short_paragraphs/it/it_0364.txt
# Writing short_paragraphs/it/it_0365.txt
# Writing short_paragraphs/it/it_0366.txt
# Writing short_paragraphs/it/it_0367.txt
# Writing short_paragraphs/it/it_0368.txt
# Writing paragraphs/it/it_0027.txt
# Writing short_paragraphs/it/it_0369.txt
# Writing short_paragraphs/it/it_0370.txt
# Writing short_paragraphs/it/it_0371.txt
# Writing short_paragraphs/it/it_0372.txt
# Writing short_paragraphs/it/it_0373.txt
# Writing short_paragraphs/it/it_0374.txt
# Writing short_paragraphs/it/it_0375.txt
# Writing short_paragraphs/it/it_0376.txt
# Writing short_paragraphs/it/it_0377.txt
# Writing short_paragraphs/it/it_0378.txt
# Writing short_paragraphs/it/it_0379.txt
# Writing short_paragraphs/it/it_0380.txt
# Writing short_paragraphs/it/it_0381.txt
# Writing short_paragraphs/it/it_0382.txt
# Writing short_paragraphs/it/it_0383.txt
# Writing short_paragraphs/it/it_0384.txt
# Writing short_paragraphs/it/it_0385.txt
# Writing short_paragraphs/it/it_0386.txt
# Writing short_paragraphs/it/it_0387.txt
# Writing short_paragraphs/it/it_0388.txt
# Writing short_paragraphs/it/it_0389.txt
# Writing short_paragraphs/it/it_0390.txt
# Writing short_paragraphs/it/it_0391.txt
# Writing short_paragraphs/it/it_0392.txt
# Writing short_paragraphs/it/it_0393.txt
# Writing paragraphs/it/it_0028.txt
# Writing short_paragraphs/it/it_0394.txt
# Writing short_paragraphs/it/it_0395.txt
# Writing short_paragraphs/it/it_0396.txt
# Writing short_paragraphs/it/it_0397.txt
# Writing short_paragraphs/it/it_0398.txt
# Writing short_paragraphs/it/it_0399.txt
# Writing short_paragraphs/it/it_0400.txt
# Writing short_paragraphs/it/it_0401.txt
# Writing short_paragraphs/it/it_0402.txt
# Writing short_paragraphs/it/it_0403.txt
# Writing short_paragraphs/it/it_0404.txt
# Writing short_paragraphs/it/it_0405.txt
# Writing short_paragraphs/it/it_0406.txt
# Writing short_paragraphs/it/it_0407.txt
# Writing short_paragraphs/it/it_0408.txt
# Writing short_paragraphs/it/it_0409.txt
# Writing short_paragraphs/it/it_0410.txt
# Writing short_paragraphs/it/it_0411.txt
# Writing short_paragraphs/it/it_0412.txt
# Writing short_paragraphs/it/it_0413.txt
# Writing paragraphs/it/it_0029.txt
# Writing short_paragraphs/it/it_0414.txt
# Writing short_paragraphs/it/it_0415.txt
# Writing short_paragraphs/it/it_0416.txt
# Writing short_paragraphs/it/it_0417.txt
# Writing short_paragraphs/it/it_0418.txt
# Writing short_paragraphs/it/it_0419.txt
# Writing short_paragraphs/it/it_0420.txt
# Writing paragraphs/it/it_0030.txt
# Writing short_paragraphs/it/it_0421.txt
# Writing short_paragraphs/it/it_0422.txt
# Writing short_paragraphs/it/it_0423.txt
# Writing short_paragraphs/it/it_0424.txt
# Writing short_paragraphs/it/it_0425.txt
# Writing paragraphs/it/it_0031.txt
# Writing short_paragraphs/it/it_0426.txt
# Writing short_paragraphs/it/it_0427.txt
# Writing short_paragraphs/it/it_0428.txt
# Writing short_paragraphs/it/it_0429.txt
# Writing short_paragraphs/it/it_0430.txt
# Writing short_paragraphs/it/it_0431.txt
# Writing short_paragraphs/it/it_0432.txt
# Writing short_paragraphs/it/it_0433.txt
# Writing short_paragraphs/it/it_0434.txt
# Writing short_paragraphs/it/it_0435.txt
# Writing short_paragraphs/it/it_0436.txt
# Writing short_paragraphs/it/it_0437.txt
# Writing paragraphs/it/it_0032.txt
# Writing short_paragraphs/it/it_0438.txt
# Writing short_paragraphs/it/it_0439.txt
# Writing short_paragraphs/it/it_0440.txt
# Writing short_paragraphs/it/it_0441.txt
# Writing paragraphs/it/it_0033.txt
# Writing short_paragraphs/it/it_0442.txt
# Writing short_paragraphs/it/it_0443.txt
# Writing short_paragraphs/it/it_0444.txt
# Writing short_paragraphs/it/it_0445.txt
# Writing short_paragraphs/it/it_0446.txt
# Writing short_paragraphs/it/it_0447.txt
# Writing short_paragraphs/it/it_0448.txt
# Writing short_paragraphs/it/it_0449.txt
# Writing paragraphs/it/it_0034.txt
# Writing short_paragraphs/it/it_0450.txt
# Writing short_paragraphs/it/it_0451.txt
# Writing short_paragraphs/it/it_0452.txt
# Writing short_paragraphs/it/it_0453.txt
# Writing short_paragraphs/it/it_0454.txt
# Writing short_paragraphs/it/it_0455.txt
# Writing short_paragraphs/it/it_0456.txt
# Writing short_paragraphs/it/it_0457.txt
# Writing short_paragraphs/it/it_0458.txt
# Writing short_paragraphs/it/it_0459.txt
# Writing paragraphs/it/it_0035.txt
# Writing short_paragraphs/it/it_0460.txt
# Writing short_paragraphs/it/it_0461.txt
# Writing short_paragraphs/it/it_0462.txt
# Writing short_paragraphs/it/it_0463.txt
# Writing short_paragraphs/it/it_0464.txt
# Writing short_paragraphs/it/it_0465.txt
# Writing short_paragraphs/it/it_0466.txt
# Writing short_paragraphs/it/it_0467.txt
# Writing short_paragraphs/it/it_0468.txt
# Writing paragraphs/it/it_0036.txt
# Writing short_paragraphs/it/it_0469.txt
# Writing short_paragraphs/it/it_0470.txt
# Writing paragraphs/it/it_0037.txt
# Writing short_paragraphs/it/it_0471.txt
# Writing short_paragraphs/it/it_0472.txt
# Writing short_paragraphs/it/it_0473.txt
# Writing short_paragraphs/it/it_0474.txt
# Writing short_paragraphs/it/it_0475.txt
# Writing short_paragraphs/it/it_0476.txt
# Writing short_paragraphs/it/it_0477.txt
# Writing short_paragraphs/it/it_0478.txt
# Writing short_paragraphs/it/it_0479.txt
# Writing short_paragraphs/it/it_0480.txt
# Writing short_paragraphs/it/it_0481.txt
# Writing short_paragraphs/it/it_0482.txt
# Writing short_paragraphs/it/it_0483.txt
# Writing short_paragraphs/it/it_0484.txt
# Writing short_paragraphs/it/it_0485.txt
# Writing short_paragraphs/it/it_0486.txt
# Writing short_paragraphs/it/it_0487.txt
# Writing short_paragraphs/it/it_0488.txt
# Writing short_paragraphs/it/it_0489.txt
# Writing short_paragraphs/it/it_0490.txt
# Writing short_paragraphs/it/it_0491.txt
# Writing short_paragraphs/it/it_0492.txt
# Writing paragraphs/it/it_0038.txt
# Writing short_paragraphs/it/it_0493.txt
# Writing short_paragraphs/it/it_0494.txt
# Writing short_paragraphs/it/it_0495.txt
# Writing short_paragraphs/it/it_0496.txt
# Writing short_paragraphs/it/it_0497.txt
# Writing short_paragraphs/it/it_0498.txt
# Writing short_paragraphs/it/it_0499.txt
# Writing short_paragraphs/it/it_0500.txt
# Writing short_paragraphs/it/it_0501.txt
# Writing short_paragraphs/it/it_0502.txt
# Writing short_paragraphs/it/it_0503.txt
# Writing short_paragraphs/it/it_0504.txt
# Writing paragraphs/it/it_0039.txt
# Writing short_paragraphs/it/it_0505.txt
# Writing short_paragraphs/it/it_0506.txt
# Writing short_paragraphs/it/it_0507.txt
# Writing short_paragraphs/it/it_0508.txt
# Writing short_paragraphs/it/it_0509.txt
# Writing short_paragraphs/it/it_0510.txt
# Writing short_paragraphs/it/it_0511.txt
# Writing short_paragraphs/it/it_0512.txt
# Writing short_paragraphs/it/it_0513.txt
# Writing short_paragraphs/it/it_0514.txt
# Writing short_paragraphs/it/it_0515.txt
# Writing short_paragraphs/it/it_0516.txt
# Writing short_paragraphs/it/it_0517.txt
# Writing short_paragraphs/it/it_0518.txt
# Writing short_paragraphs/it/it_0519.txt
# Writing short_paragraphs/it/it_0520.txt
# Writing short_paragraphs/it/it_0521.txt
# Writing short_paragraphs/it/it_0522.txt
# Writing short_paragraphs/it/it_0523.txt
# Writing short_paragraphs/it/it_0524.txt
# Writing short_paragraphs/it/it_0525.txt
# Writing short_paragraphs/it/it_0526.txt
# Writing short_paragraphs/it/it_0527.txt
# Writing short_paragraphs/it/it_0528.txt
# Writing short_paragraphs/it/it_0529.txt
# Writing short_paragraphs/it/it_0530.txt
# Writing short_paragraphs/it/it_0531.txt
# Writing paragraphs/it/it_0040.txt
# Writing short_paragraphs/it/it_0532.txt
# Writing short_paragraphs/it/it_0533.txt
# Writing short_paragraphs/it/it_0534.txt
# Writing short_paragraphs/it/it_0535.txt
# Writing short_paragraphs/it/it_0536.txt
# Writing short_paragraphs/it/it_0537.txt
# Writing short_paragraphs/it/it_0538.txt
# Writing short_paragraphs/it/it_0539.txt
# Writing short_paragraphs/it/it_0540.txt
# Writing short_paragraphs/it/it_0541.txt
# Writing short_paragraphs/it/it_0542.txt
# Writing short_paragraphs/it/it_0543.txt
# Writing short_paragraphs/it/it_0544.txt
# Writing short_paragraphs/it/it_0545.txt
# Writing short_paragraphs/it/it_0546.txt
# Writing short_paragraphs/it/it_0547.txt
# Writing short_paragraphs/it/it_0548.txt
# Writing short_paragraphs/it/it_0549.txt
# Writing short_paragraphs/it/it_0550.txt
# Writing short_paragraphs/it/it_0551.txt
# Writing short_paragraphs/it/it_0552.txt
# Writing short_paragraphs/it/it_0553.txt
# Writing short_paragraphs/it/it_0554.txt
# Writing paragraphs/it/it_0041.txt
# Writing short_paragraphs/it/it_0555.txt
# Writing short_paragraphs/it/it_0556.txt
# Writing short_paragraphs/it/it_0557.txt
# Writing short_paragraphs/it/it_0558.txt
# Writing short_paragraphs/it/it_0559.txt
# Writing paragraphs/it/it_0042.txt
# Writing short_paragraphs/it/it_0560.txt
# Writing short_paragraphs/it/it_0561.txt
# Writing short_paragraphs/it/it_0562.txt
# Writing short_paragraphs/it/it_0563.txt
# Writing short_paragraphs/it/it_0564.txt
# Writing short_paragraphs/it/it_0565.txt
# Writing short_paragraphs/it/it_0566.txt
# Writing short_paragraphs/it/it_0567.txt
# Writing paragraphs/it/it_0043.txt
# Writing short_paragraphs/it/it_0568.txt
# Writing short_paragraphs/it/it_0569.txt
# Writing short_paragraphs/it/it_0570.txt
# Writing short_paragraphs/it/it_0571.txt
# Writing short_paragraphs/it/it_0572.txt
# Writing short_paragraphs/it/it_0573.txt
# Writing short_paragraphs/it/it_0574.txt
# Writing short_paragraphs/it/it_0575.txt
# Writing short_paragraphs/it/it_0576.txt
# Writing short_paragraphs/it/it_0577.txt
# Writing short_paragraphs/it/it_0578.txt
# Writing short_paragraphs/it/it_0579.txt
# Writing short_paragraphs/it/it_0580.txt
# Writing short_paragraphs/it/it_0581.txt
# Writing short_paragraphs/it/it_0582.txt
# Writing short_paragraphs/it/it_0583.txt
# Writing short_paragraphs/it/it_0584.txt
# Writing short_paragraphs/it/it_0585.txt
# Writing short_paragraphs/it/it_0586.txt
# Writing short_paragraphs/it/it_0587.txt
# Writing short_paragraphs/it/it_0588.txt
# Writing short_paragraphs/it/it_0589.txt
# Writing paragraphs/it/it_0044.txt
# Writing short_paragraphs/it/it_0590.txt
# Writing short_paragraphs/it/it_0591.txt
# Writing short_paragraphs/it/it_0592.txt
# Writing short_paragraphs/it/it_0593.txt
# Writing short_paragraphs/it/it_0594.txt
# Writing short_paragraphs/it/it_0595.txt
# Writing short_paragraphs/it/it_0596.txt
# Writing short_paragraphs/it/it_0597.txt
# Writing short_paragraphs/it/it_0598.txt
# Writing short_paragraphs/it/it_0599.txt
# Writing short_paragraphs/it/it_0600.txt
# Writing short_paragraphs/it/it_0601.txt
# Writing short_paragraphs/it/it_0602.txt
# Writing short_paragraphs/it/it_0603.txt
# Writing short_paragraphs/it/it_0604.txt
# Writing short_paragraphs/it/it_0605.txt
# Writing short_paragraphs/it/it_0606.txt
# Writing short_paragraphs/it/it_0607.txt
# Writing short_paragraphs/it/it_0608.txt
# Writing short_paragraphs/it/it_0609.txt
# Writing short_paragraphs/it/it_0610.txt
# Writing short_paragraphs/it/it_0611.txt
# Writing short_paragraphs/it/it_0612.txt
# Writing short_paragraphs/it/it_0613.txt
# Writing short_paragraphs/it/it_0614.txt
# Writing short_paragraphs/it/it_0615.txt
# Writing short_paragraphs/it/it_0616.txt
# Writing short_paragraphs/it/it_0617.txt
# Writing short_paragraphs/it/it_0618.txt
# Writing short_paragraphs/it/it_0619.txt
# Writing short_paragraphs/it/it_0620.txt
# Writing short_paragraphs/it/it_0621.txt
# Writing paragraphs/it/it_0045.txt
# Writing short_paragraphs/it/it_0622.txt
# Writing short_paragraphs/it/it_0623.txt
# Writing short_paragraphs/it/it_0624.txt
# Writing short_paragraphs/it/it_0625.txt
# Writing short_paragraphs/it/it_0626.txt
# Writing short_paragraphs/it/it_0627.txt
# Writing short_paragraphs/it/it_0628.txt
# Writing short_paragraphs/it/it_0629.txt
# Writing short_paragraphs/it/it_0630.txt
# Writing short_paragraphs/it/it_0631.txt
# Writing short_paragraphs/it/it_0632.txt
# Writing short_paragraphs/it/it_0633.txt
# Writing short_paragraphs/it/it_0634.txt
# Writing short_paragraphs/it/it_0635.txt
# Writing short_paragraphs/it/it_0636.txt
# Writing short_paragraphs/it/it_0637.txt
# Writing short_paragraphs/it/it_0638.txt
# Writing short_paragraphs/it/it_0639.txt
# Writing short_paragraphs/it/it_0640.txt
# Writing short_paragraphs/it/it_0641.txt
# Writing short_paragraphs/it/it_0642.txt
# Writing short_paragraphs/it/it_0643.txt
# Writing short_paragraphs/it/it_0644.txt
# Writing short_paragraphs/it/it_0645.txt
# Writing short_paragraphs/it/it_0646.txt
# Writing short_paragraphs/it/it_0647.txt
# Writing short_paragraphs/it/it_0648.txt
# Writing paragraphs/it/it_0046.txt
# Writing short_paragraphs/it/it_0649.txt
# Writing short_paragraphs/it/it_0650.txt
# Writing short_paragraphs/it/it_0651.txt
# Writing short_paragraphs/it/it_0652.txt
# Writing short_paragraphs/it/it_0653.txt
# Writing short_paragraphs/it/it_0654.txt
# Writing short_paragraphs/it/it_0655.txt
# Writing short_paragraphs/it/it_0656.txt
# Writing short_paragraphs/it/it_0657.txt
# Writing short_paragraphs/it/it_0658.txt
# Writing short_paragraphs/it/it_0659.txt
# Writing short_paragraphs/it/it_0660.txt
# Writing short_paragraphs/it/it_0661.txt
# Writing short_paragraphs/it/it_0662.txt
# Writing short_paragraphs/it/it_0663.txt
# Writing short_paragraphs/it/it_0664.txt
# Writing short_paragraphs/it/it_0665.txt
# Writing short_paragraphs/it/it_0666.txt
# Writing short_paragraphs/it/it_0667.txt
# Writing short_paragraphs/it/it_0668.txt
# Writing short_paragraphs/it/it_0669.txt
# Writing short_paragraphs/it/it_0670.txt
# Writing short_paragraphs/it/it_0671.txt
# Writing short_paragraphs/it/it_0672.txt
# Writing short_paragraphs/it/it_0673.txt
# Writing paragraphs/it/it_0047.txt
# Writing short_paragraphs/it/it_0674.txt
# Writing short_paragraphs/it/it_0675.txt
# Writing short_paragraphs/it/it_0676.txt
# Writing short_paragraphs/it/it_0677.txt
# Writing short_paragraphs/it/it_0678.txt
# Writing short_paragraphs/it/it_0679.txt
# Writing short_paragraphs/it/it_0680.txt
# Writing short_paragraphs/it/it_0681.txt
# Writing short_paragraphs/it/it_0682.txt
# Writing short_paragraphs/it/it_0683.txt
# Writing paragraphs/it/it_0048.txt
# Writing short_paragraphs/it/it_0684.txt
# Writing short_paragraphs/it/it_0685.txt
# Writing short_paragraphs/it/it_0686.txt
# Writing short_paragraphs/it/it_0687.txt
# Writing short_paragraphs/it/it_0688.txt
# Writing short_paragraphs/it/it_0689.txt
# Writing short_paragraphs/it/it_0690.txt
# Writing short_paragraphs/it/it_0691.txt
# Writing short_paragraphs/it/it_0692.txt
# Writing short_paragraphs/it/it_0693.txt
# Writing short_paragraphs/it/it_0694.txt
# Writing short_paragraphs/it/it_0695.txt
# Writing short_paragraphs/it/it_0696.txt
# Writing short_paragraphs/it/it_0697.txt
# Writing short_paragraphs/it/it_0698.txt
# Writing short_paragraphs/it/it_0699.txt
# Writing short_paragraphs/it/it_0700.txt
# Writing short_paragraphs/it/it_0701.txt
# Writing short_paragraphs/it/it_0702.txt
# Writing short_paragraphs/it/it_0703.txt
# Writing short_paragraphs/it/it_0704.txt
# Writing short_paragraphs/it/it_0705.txt
# Writing short_paragraphs/it/it_0706.txt
# Writing short_paragraphs/it/it_0707.txt
# Writing short_paragraphs/it/it_0708.txt
# Writing short_paragraphs/it/it_0709.txt
# Writing paragraphs/it/it_0049.txt
# Writing short_paragraphs/it/it_0710.txt
# Writing short_paragraphs/it/it_0711.txt
# Writing short_paragraphs/it/it_0712.txt
# Writing short_paragraphs/it/it_0713.txt
# Writing short_paragraphs/it/it_0714.txt
# Writing short_paragraphs/it/it_0715.txt
# Writing short_paragraphs/it/it_0716.txt
# Writing short_paragraphs/it/it_0717.txt
# Writing short_paragraphs/it/it_0718.txt
# Writing short_paragraphs/it/it_0719.txt
# Writing short_paragraphs/it/it_0720.txt
# Writing short_paragraphs/it/it_0721.txt
# Writing short_paragraphs/it/it_0722.txt
# Writing short_paragraphs/it/it_0723.txt
# Writing short_paragraphs/it/it_0724.txt
# Writing short_paragraphs/it/it_0725.txt
# Writing short_paragraphs/it/it_0726.txt
# Writing short_paragraphs/it/it_0727.txt
# Writing short_paragraphs/it/it_0728.txt
# Writing short_paragraphs/it/it_0729.txt
# Writing short_paragraphs/it/it_0730.txt
# Writing short_paragraphs/it/it_0731.txt
# Writing paragraphs/it/it_0050.txt
# Writing short_paragraphs/it/it_0732.txt
# Writing short_paragraphs/it/it_0733.txt
# Writing short_paragraphs/it/it_0734.txt
# Writing short_paragraphs/it/it_0735.txt
# Writing short_paragraphs/it/it_0736.txt
# Writing short_paragraphs/it/it_0737.txt
# Writing short_paragraphs/it/it_0738.txt
# Writing short_paragraphs/it/it_0739.txt
# Writing paragraphs/it/it_0051.txt
# Writing short_paragraphs/it/it_0740.txt
# Writing short_paragraphs/it/it_0741.txt
# Writing short_paragraphs/it/it_0742.txt
# Writing short_paragraphs/it/it_0743.txt
# Writing short_paragraphs/it/it_0744.txt
# Writing short_paragraphs/it/it_0745.txt
# Writing short_paragraphs/it/it_0746.txt
# Writing short_paragraphs/it/it_0747.txt
# Writing short_paragraphs/it/it_0748.txt
# Writing short_paragraphs/it/it_0749.txt
# Writing short_paragraphs/it/it_0750.txt
# Writing short_paragraphs/it/it_0751.txt
# Writing short_paragraphs/it/it_0752.txt
# Writing short_paragraphs/it/it_0753.txt
# Writing short_paragraphs/it/it_0754.txt
# Writing short_paragraphs/it/it_0755.txt
# Writing paragraphs/it/it_0052.txt
# Writing short_paragraphs/it/it_0756.txt
# Writing short_paragraphs/it/it_0757.txt
# Writing short_paragraphs/it/it_0758.txt
# Writing short_paragraphs/it/it_0759.txt
# Writing short_paragraphs/it/it_0760.txt
# Writing short_paragraphs/it/it_0761.txt
# Writing short_paragraphs/it/it_0762.txt
# Writing short_paragraphs/it/it_0763.txt
# Writing paragraphs/it/it_0053.txt
# Writing short_paragraphs/it/it_0764.txt
# Writing short_paragraphs/it/it_0765.txt
# Writing short_paragraphs/it/it_0766.txt
# Writing short_paragraphs/it/it_0767.txt
# Writing short_paragraphs/it/it_0768.txt
# Writing short_paragraphs/it/it_0769.txt
# Writing paragraphs/it/it_0054.txt
# Writing short_paragraphs/it/it_0770.txt
# Writing short_paragraphs/it/it_0771.txt
# Writing short_paragraphs/it/it_0772.txt
# Writing short_paragraphs/it/it_0773.txt
# Writing short_paragraphs/it/it_0774.txt
# Writing paragraphs/it/it_0055.txt
# Writing short_paragraphs/it/it_0775.txt
# Writing short_paragraphs/it/it_0776.txt
# Writing short_paragraphs/it/it_0777.txt
# Writing short_paragraphs/it/it_0778.txt
# Writing short_paragraphs/it/it_0779.txt
# Writing short_paragraphs/it/it_0780.txt
# Writing short_paragraphs/it/it_0781.txt
# Writing short_paragraphs/it/it_0782.txt
# Writing short_paragraphs/it/it_0783.txt
# Writing short_paragraphs/it/it_0784.txt
# Writing short_paragraphs/it/it_0785.txt
# Writing short_paragraphs/it/it_0786.txt
# Writing short_paragraphs/it/it_0787.txt
# Writing short_paragraphs/it/it_0788.txt
# Writing short_paragraphs/it/it_0789.txt
# Writing short_paragraphs/it/it_0790.txt
# Writing short_paragraphs/it/it_0791.txt
# Writing short_paragraphs/it/it_0792.txt
# Writing paragraphs/it/it_0056.txt
# Writing short_paragraphs/it/it_0793.txt
# Writing short_paragraphs/it/it_0794.txt
# Writing short_paragraphs/it/it_0795.txt
# Writing short_paragraphs/it/it_0796.txt
# Writing short_paragraphs/it/it_0797.txt
# Writing short_paragraphs/it/it_0798.txt
# Writing short_paragraphs/it/it_0799.txt
# Writing short_paragraphs/it/it_0800.txt
# Writing short_paragraphs/it/it_0801.txt
# Writing short_paragraphs/it/it_0802.txt
# Writing short_paragraphs/it/it_0803.txt
# Writing short_paragraphs/it/it_0804.txt
# Writing short_paragraphs/it/it_0805.txt
# Writing short_paragraphs/it/it_0806.txt
# Writing short_paragraphs/it/it_0807.txt
# Writing short_paragraphs/it/it_0808.txt
# Writing short_paragraphs/it/it_0809.txt
# Writing short_paragraphs/it/it_0810.txt
# Writing short_paragraphs/it/it_0811.txt
# Writing paragraphs/it/it_0057.txt
# Writing short_paragraphs/it/it_0812.txt
# Writing short_paragraphs/it/it_0813.txt
# Writing short_paragraphs/it/it_0814.txt
# Writing short_paragraphs/it/it_0815.txt
# Writing short_paragraphs/it/it_0816.txt
# Writing short_paragraphs/it/it_0817.txt
# Writing short_paragraphs/it/it_0818.txt
# Writing short_paragraphs/it/it_0819.txt
# Writing short_paragraphs/it/it_0820.txt
# Writing short_paragraphs/it/it_0821.txt
# Writing short_paragraphs/it/it_0822.txt
# Writing short_paragraphs/it/it_0823.txt
# Writing short_paragraphs/it/it_0824.txt
# Writing paragraphs/it/it_0058.txt
# Writing short_paragraphs/it/it_0825.txt
# Writing short_paragraphs/it/it_0826.txt
# Writing short_paragraphs/it/it_0827.txt
# Writing short_paragraphs/it/it_0828.txt
# Writing short_paragraphs/it/it_0829.txt
# Writing short_paragraphs/it/it_0830.txt
# Writing short_paragraphs/it/it_0831.txt
# Writing short_paragraphs/it/it_0832.txt
# Writing short_paragraphs/it/it_0833.txt
# Writing short_paragraphs/it/it_0834.txt
# Writing short_paragraphs/it/it_0835.txt
# Writing short_paragraphs/it/it_0836.txt
# Writing short_paragraphs/it/it_0837.txt
# Writing short_paragraphs/it/it_0838.txt
# Writing short_paragraphs/it/it_0839.txt
# Writing short_paragraphs/it/it_0840.txt
# Writing short_paragraphs/it/it_0841.txt
# Writing short_paragraphs/it/it_0842.txt
# Writing short_paragraphs/it/it_0843.txt
# Writing short_paragraphs/it/it_0844.txt
# Writing short_paragraphs/it/it_0845.txt
# Writing short_paragraphs/it/it_0846.txt
# Writing short_paragraphs/it/it_0847.txt
# Writing short_paragraphs/it/it_0848.txt
# Writing short_paragraphs/it/it_0849.txt
# Writing short_paragraphs/it/it_0850.txt
# Writing short_paragraphs/it/it_0851.txt
# Writing paragraphs/it/it_0059.txt
# Writing short_paragraphs/it/it_0852.txt
# Writing short_paragraphs/it/it_0853.txt
# Writing short_paragraphs/it/it_0854.txt
# Writing short_paragraphs/it/it_0855.txt
# Writing short_paragraphs/it/it_0856.txt
# Writing short_paragraphs/it/it_0857.txt
# Writing short_paragraphs/it/it_0858.txt
# Writing short_paragraphs/it/it_0859.txt
# Writing short_paragraphs/it/it_0860.txt
# Writing short_paragraphs/it/it_0861.txt
# Writing short_paragraphs/it/it_0862.txt
# Writing short_paragraphs/it/it_0863.txt
# Writing short_paragraphs/it/it_0864.txt
# Writing paragraphs/it/it_0060.txt
# Writing short_paragraphs/it/it_0865.txt
# Writing short_paragraphs/it/it_0866.txt
# Writing short_paragraphs/it/it_0867.txt
# Writing short_paragraphs/it/it_0868.txt
# Writing short_paragraphs/it/it_0869.txt
# Writing short_paragraphs/it/it_0870.txt
# Writing short_paragraphs/it/it_0871.txt
# Writing short_paragraphs/it/it_0872.txt
# Writing short_paragraphs/it/it_0873.txt
# Writing short_paragraphs/it/it_0874.txt
# Writing short_paragraphs/it/it_0875.txt
# Writing short_paragraphs/it/it_0876.txt
# Writing short_paragraphs/it/it_0877.txt
# Writing short_paragraphs/it/it_0878.txt
# Writing short_paragraphs/it/it_0879.txt
# Writing short_paragraphs/it/it_0880.txt
# Writing short_paragraphs/it/it_0881.txt
# Writing short_paragraphs/it/it_0882.txt
# Writing short_paragraphs/it/it_0883.txt
# Writing short_paragraphs/it/it_0884.txt
# Writing short_paragraphs/it/it_0885.txt
# Writing short_paragraphs/it/it_0886.txt
# Writing short_paragraphs/it/it_0887.txt
# Writing short_paragraphs/it/it_0888.txt
# Writing short_paragraphs/it/it_0889.txt
# Writing short_paragraphs/it/it_0890.txt
# Writing short_paragraphs/it/it_0891.txt
# Writing short_paragraphs/it/it_0892.txt
# Writing short_paragraphs/it/it_0893.txt
# Writing short_paragraphs/it/it_0894.txt
# Writing short_paragraphs/it/it_0895.txt
# Writing short_paragraphs/it/it_0896.txt
# Writing short_paragraphs/it/it_0897.txt
# Writing short_paragraphs/it/it_0898.txt
# Writing paragraphs/it/it_0061.txt
# Writing short_paragraphs/it/it_0899.txt
# Writing short_paragraphs/it/it_0900.txt
# Writing short_paragraphs/it/it_0901.txt
# Writing short_paragraphs/it/it_0902.txt
# Writing short_paragraphs/it/it_0903.txt
# Writing short_paragraphs/it/it_0904.txt
# Writing short_paragraphs/it/it_0905.txt
# Writing short_paragraphs/it/it_0906.txt
# Writing short_paragraphs/it/it_0907.txt
# Writing short_paragraphs/it/it_0908.txt
# Writing short_paragraphs/it/it_0909.txt
# Writing short_paragraphs/it/it_0910.txt
# Writing short_paragraphs/it/it_0911.txt
# Writing short_paragraphs/it/it_0912.txt
# Writing short_paragraphs/it/it_0913.txt
# Writing short_paragraphs/it/it_0914.txt
# Writing short_paragraphs/it/it_0915.txt
# Writing short_paragraphs/it/it_0916.txt
# Writing short_paragraphs/it/it_0917.txt
# Writing short_paragraphs/it/it_0918.txt
# Writing short_paragraphs/it/it_0919.txt
# Writing short_paragraphs/it/it_0920.txt
# Writing short_paragraphs/it/it_0921.txt
# Writing short_paragraphs/it/it_0922.txt
# Writing paragraphs/it/it_0062.txt
# Writing short_paragraphs/it/it_0923.txt
# Writing short_paragraphs/it/it_0924.txt
# Writing short_paragraphs/it/it_0925.txt
# Writing short_paragraphs/it/it_0926.txt
# Writing short_paragraphs/it/it_0927.txt
# Writing short_paragraphs/it/it_0928.txt
# Writing short_paragraphs/it/it_0929.txt
# Writing short_paragraphs/it/it_0930.txt
# Writing paragraphs/it/it_0063.txt
# Writing short_paragraphs/it/it_0931.txt
# Writing short_paragraphs/it/it_0932.txt
# Writing short_paragraphs/it/it_0933.txt
# Writing short_paragraphs/it/it_0934.txt
# Writing short_paragraphs/it/it_0935.txt
# Writing short_paragraphs/it/it_0936.txt
# Writing short_paragraphs/it/it_0937.txt
# Writing short_paragraphs/it/it_0938.txt
# Writing short_paragraphs/it/it_0939.txt
# Writing short_paragraphs/it/it_0940.txt
# Writing short_paragraphs/it/it_0941.txt
# Writing short_paragraphs/it/it_0942.txt
# Writing short_paragraphs/it/it_0943.txt
# Writing short_paragraphs/it/it_0944.txt
# Writing paragraphs/it/it_0064.txt
# Writing short_paragraphs/it/it_0945.txt
# Writing short_paragraphs/it/it_0946.txt
# Writing short_paragraphs/it/it_0947.txt
# Writing short_paragraphs/it/it_0948.txt
# Writing short_paragraphs/it/it_0949.txt
# Writing paragraphs/it/it_0065.txt
# Writing short_paragraphs/it/it_0950.txt
# Writing short_paragraphs/it/it_0951.txt
# Writing short_paragraphs/it/it_0952.txt
# Writing short_paragraphs/it/it_0953.txt
# Writing short_paragraphs/it/it_0954.txt
# Writing short_paragraphs/it/it_0955.txt
# Writing short_paragraphs/it/it_0956.txt
# Writing short_paragraphs/it/it_0957.txt
# Writing short_paragraphs/it/it_0958.txt
# Writing short_paragraphs/it/it_0959.txt
# Writing short_paragraphs/it/it_0960.txt
# Writing short_paragraphs/it/it_0961.txt
# Writing paragraphs/it/it_0066.txt
# Writing short_paragraphs/it/it_0962.txt
# Writing short_paragraphs/it/it_0963.txt
# Writing short_paragraphs/it/it_0964.txt
# Writing short_paragraphs/it/it_0965.txt
# Writing short_paragraphs/it/it_0966.txt
# Writing short_paragraphs/it/it_0967.txt
# Writing short_paragraphs/it/it_0968.txt
# Writing short_paragraphs/it/it_0969.txt
# Writing short_paragraphs/it/it_0970.txt
# Writing short_paragraphs/it/it_0971.txt
# Writing short_paragraphs/it/it_0972.txt
# Writing short_paragraphs/it/it_0973.txt
# Writing short_paragraphs/it/it_0974.txt
# Writing short_paragraphs/it/it_0975.txt
# Writing short_paragraphs/it/it_0976.txt
# Writing short_paragraphs/it/it_0977.txt
# Writing short_paragraphs/it/it_0978.txt
# Writing short_paragraphs/it/it_0979.txt
# Writing short_paragraphs/it/it_0980.txt
# Writing short_paragraphs/it/it_0981.txt
# Writing paragraphs/it/it_0067.txt
# Writing short_paragraphs/it/it_0982.txt
# Writing short_paragraphs/it/it_0983.txt
# Writing short_paragraphs/it/it_0984.txt
# Writing short_paragraphs/it/it_0985.txt
# Writing short_paragraphs/it/it_0986.txt
# Writing short_paragraphs/it/it_0987.txt
# Writing short_paragraphs/it/it_0988.txt
# Writing short_paragraphs/it/it_0989.txt
# Writing short_paragraphs/it/it_0990.txt
# Writing short_paragraphs/it/it_0991.txt
# Writing short_paragraphs/it/it_0992.txt
# Writing short_paragraphs/it/it_0993.txt
# Writing short_paragraphs/it/it_0994.txt
# Writing short_paragraphs/it/it_0995.txt
# Writing short_paragraphs/it/it_0996.txt
# Writing short_paragraphs/it/it_0997.txt
# Writing short_paragraphs/it/it_0998.txt
# Writing short_paragraphs/it/it_0999.txt
# Writing paragraphs/it/it_0068.txt
# Writing short_paragraphs/it/it_1000.txt
# Writing paragraphs/it/it_0069.txt
# Writing short_paragraphs/it/it_1001.txt
# Writing paragraphs/it/it_0070.txt
# Writing short_paragraphs/it/it_1002.txt
# Writing paragraphs/it/it_0071.txt
# Writing short_paragraphs/it/it_1003.txt
# Writing paragraphs/it/it_0072.txt
# Writing short_paragraphs/it/it_1004.txt
# Writing paragraphs/it/it_0073.txt
# Writing short_paragraphs/it/it_1005.txt
# Writing paragraphs/it/it_0074.txt
# Writing short_paragraphs/it/it_1006.txt
# Writing paragraphs/it/it_0075.txt
# Writing short_paragraphs/it/it_1007.txt
# Writing paragraphs/it/it_0076.txt
# Writing short_paragraphs/it/it_1008.txt
# Writing paragraphs/it/it_0077.txt
# Writing short_paragraphs/it/it_1009.txt
# Writing paragraphs/it/it_0078.txt
# Writing short_paragraphs/it/it_1010.txt
# Writing paragraphs/it/it_0079.txt
# Writing short_paragraphs/it/it_1011.txt
# Writing paragraphs/it/it_0080.txt
# Writing short_paragraphs/it/it_1012.txt
# Writing paragraphs/it/it_0081.txt
# Writing short_paragraphs/it/it_1013.txt
# Writing paragraphs/it/it_0082.txt
# Writing short_paragraphs/it/it_1014.txt
# Writing paragraphs/it/it_0083.txt
# Writing short_paragraphs/it/it_1015.txt
# Writing paragraphs/it/it_0084.txt
# Writing short_paragraphs/it/it_1016.txt
# Downloading http://ja.wikipedia.org/wiki/Wikipedia
# Writing paragraphs/ja/ja_0000.txt
# Writing paragraphs/ja/ja_0001.txt
# Writing paragraphs/ja/ja_0002.txt
# Writing paragraphs/ja/ja_0003.txt
# Writing paragraphs/ja/ja_0004.txt
# Writing paragraphs/ja/ja_0005.txt
# Writing paragraphs/ja/ja_0006.txt
# Writing paragraphs/ja/ja_0007.txt
# Writing paragraphs/ja/ja_0008.txt
# Writing paragraphs/ja/ja_0009.txt
# Writing paragraphs/ja/ja_0010.txt
# Writing paragraphs/ja/ja_0011.txt
# Writing paragraphs/ja/ja_0012.txt
# Writing paragraphs/ja/ja_0013.txt
# Writing paragraphs/ja/ja_0014.txt
# Writing paragraphs/ja/ja_0015.txt
# Writing paragraphs/ja/ja_0016.txt
# Writing paragraphs/ja/ja_0017.txt
# Writing paragraphs/ja/ja_0018.txt
# Writing paragraphs/ja/ja_0019.txt
# Writing paragraphs/ja/ja_0020.txt
# Writing paragraphs/ja/ja_0021.txt
# Writing paragraphs/ja/ja_0022.txt
# Writing paragraphs/ja/ja_0023.txt
# Writing paragraphs/ja/ja_0024.txt
# Writing paragraphs/ja/ja_0025.txt
# Writing paragraphs/ja/ja_0026.txt
# Writing paragraphs/ja/ja_0027.txt
# Writing paragraphs/ja/ja_0028.txt
# Writing paragraphs/ja/ja_0029.txt
# Writing paragraphs/ja/ja_0030.txt
# Writing paragraphs/ja/ja_0031.txt
# Writing paragraphs/ja/ja_0032.txt
# Writing paragraphs/ja/ja_0033.txt
# Writing paragraphs/ja/ja_0034.txt
# Writing paragraphs/ja/ja_0035.txt
# Writing paragraphs/ja/ja_0036.txt
# Writing paragraphs/ja/ja_0037.txt
# Writing paragraphs/ja/ja_0038.txt
# Writing paragraphs/ja/ja_0039.txt
# Writing paragraphs/ja/ja_0040.txt
# Writing paragraphs/ja/ja_0041.txt
# Writing paragraphs/ja/ja_0042.txt
# Writing paragraphs/ja/ja_0043.txt
# Writing paragraphs/ja/ja_0044.txt
# Writing paragraphs/ja/ja_0045.txt
# Writing paragraphs/ja/ja_0046.txt
# Writing paragraphs/ja/ja_0047.txt
# Writing paragraphs/ja/ja_0048.txt
# Writing paragraphs/ja/ja_0049.txt
# Writing paragraphs/ja/ja_0050.txt
# Writing paragraphs/ja/ja_0051.txt
# Writing paragraphs/ja/ja_0052.txt
# Writing paragraphs/ja/ja_0053.txt
# Writing paragraphs/ja/ja_0054.txt
# Writing paragraphs/ja/ja_0055.txt
# Writing paragraphs/ja/ja_0056.txt
# Writing paragraphs/ja/ja_0057.txt
# Writing paragraphs/ja/ja_0058.txt
# Writing paragraphs/ja/ja_0059.txt
# Writing paragraphs/ja/ja_0060.txt
# Writing paragraphs/ja/ja_0061.txt
# Writing paragraphs/ja/ja_0062.txt
# Writing paragraphs/ja/ja_0063.txt
# Writing paragraphs/ja/ja_0064.txt
# Writing paragraphs/ja/ja_0065.txt
# Writing paragraphs/ja/ja_0066.txt
# Writing paragraphs/ja/ja_0067.txt
# Writing paragraphs/ja/ja_0068.txt
# Writing paragraphs/ja/ja_0069.txt
# Writing paragraphs/ja/ja_0070.txt
# Writing paragraphs/ja/ja_0071.txt
# Writing paragraphs/ja/ja_0072.txt
# Writing paragraphs/ja/ja_0073.txt
# Writing paragraphs/ja/ja_0074.txt
# Downloading http://nl.wikipedia.org/wiki/Wikipedia
# Writing paragraphs/nl/nl_0000.txt
# Writing short_paragraphs/nl/nl_0000.txt
# Writing short_paragraphs/nl/nl_0001.txt
# Writing short_paragraphs/nl/nl_0002.txt
# Writing short_paragraphs/nl/nl_0003.txt
# Writing short_paragraphs/nl/nl_0004.txt
# Writing short_paragraphs/nl/nl_0005.txt
# Writing short_paragraphs/nl/nl_0006.txt
# Writing short_paragraphs/nl/nl_0007.txt
# Writing short_paragraphs/nl/nl_0008.txt
# Writing paragraphs/nl/nl_0001.txt
# Writing short_paragraphs/nl/nl_0009.txt
# Writing short_paragraphs/nl/nl_0010.txt
# Writing short_paragraphs/nl/nl_0011.txt
# Writing short_paragraphs/nl/nl_0012.txt
# Writing short_paragraphs/nl/nl_0013.txt
# Writing short_paragraphs/nl/nl_0014.txt
# Writing short_paragraphs/nl/nl_0015.txt
# Writing short_paragraphs/nl/nl_0016.txt
# Writing short_paragraphs/nl/nl_0017.txt
# Writing short_paragraphs/nl/nl_0018.txt
# Writing paragraphs/nl/nl_0002.txt
# Writing short_paragraphs/nl/nl_0019.txt
# Writing short_paragraphs/nl/nl_0020.txt
# Writing short_paragraphs/nl/nl_0021.txt
# Writing paragraphs/nl/nl_0003.txt
# Writing short_paragraphs/nl/nl_0022.txt
# Writing short_paragraphs/nl/nl_0023.txt
# Writing short_paragraphs/nl/nl_0024.txt
# Writing short_paragraphs/nl/nl_0025.txt
# Writing short_paragraphs/nl/nl_0026.txt
# Writing short_paragraphs/nl/nl_0027.txt
# Writing paragraphs/nl/nl_0004.txt
# Writing short_paragraphs/nl/nl_0028.txt
# Writing short_paragraphs/nl/nl_0029.txt
# Writing short_paragraphs/nl/nl_0030.txt
# Writing short_paragraphs/nl/nl_0031.txt
# Writing short_paragraphs/nl/nl_0032.txt
# Writing short_paragraphs/nl/nl_0033.txt
# Writing short_paragraphs/nl/nl_0034.txt
# Writing short_paragraphs/nl/nl_0035.txt
# Writing short_paragraphs/nl/nl_0036.txt
# Writing short_paragraphs/nl/nl_0037.txt
# Writing short_paragraphs/nl/nl_0038.txt
# Writing short_paragraphs/nl/nl_0039.txt
# Writing short_paragraphs/nl/nl_0040.txt
# Writing short_paragraphs/nl/nl_0041.txt
# Writing short_paragraphs/nl/nl_0042.txt
# Writing short_paragraphs/nl/nl_0043.txt
# Writing short_paragraphs/nl/nl_0044.txt
# Writing short_paragraphs/nl/nl_0045.txt
# Writing short_paragraphs/nl/nl_0046.txt
# Writing short_paragraphs/nl/nl_0047.txt
# Writing short_paragraphs/nl/nl_0048.txt
# Writing short_paragraphs/nl/nl_0049.txt
# Writing short_paragraphs/nl/nl_0050.txt
# Writing short_paragraphs/nl/nl_0051.txt
# Writing short_paragraphs/nl/nl_0052.txt
# Writing short_paragraphs/nl/nl_0053.txt
# Writing short_paragraphs/nl/nl_0054.txt
# Writing paragraphs/nl/nl_0005.txt
# Writing short_paragraphs/nl/nl_0055.txt
# Writing short_paragraphs/nl/nl_0056.txt
# Writing short_paragraphs/nl/nl_0057.txt
# Writing short_paragraphs/nl/nl_0058.txt
# Writing short_paragraphs/nl/nl_0059.txt
# Writing short_paragraphs/nl/nl_0060.txt
# Writing short_paragraphs/nl/nl_0061.txt
# Writing short_paragraphs/nl/nl_0062.txt
# Writing short_paragraphs/nl/nl_0063.txt
# Writing short_paragraphs/nl/nl_0064.txt
# Writing short_paragraphs/nl/nl_0065.txt
# Writing short_paragraphs/nl/nl_0066.txt
# Writing short_paragraphs/nl/nl_0067.txt
# Writing short_paragraphs/nl/nl_0068.txt
# Writing short_paragraphs/nl/nl_0069.txt
# Writing short_paragraphs/nl/nl_0070.txt
# Writing short_paragraphs/nl/nl_0071.txt
# Writing short_paragraphs/nl/nl_0072.txt
# Writing short_paragraphs/nl/nl_0073.txt
# Writing short_paragraphs/nl/nl_0074.txt
# Writing short_paragraphs/nl/nl_0075.txt
# Writing short_paragraphs/nl/nl_0076.txt
# Writing short_paragraphs/nl/nl_0077.txt
# Writing short_paragraphs/nl/nl_0078.txt
# Writing short_paragraphs/nl/nl_0079.txt
# Writing short_paragraphs/nl/nl_0080.txt
# Writing short_paragraphs/nl/nl_0081.txt
# Writing short_paragraphs/nl/nl_0082.txt
# Writing paragraphs/nl/nl_0006.txt
# Writing short_paragraphs/nl/nl_0083.txt
# Writing short_paragraphs/nl/nl_0084.txt
# ...
# Writing short_paragraphs/ru/ru_0588.txt
# Writing short_paragraphs/ru/ru_0589.txt
# Writing paragraphs/ru/ru_0039.txt
# Writing short_paragraphs/ru/ru_0590.txt
# Writing short_paragraphs/ru/ru_0591.txt
# Writing short_paragraphs/ru/ru_0592.txt
# Writing short_paragraphs/ru/ru_0593.txt
# Writing short_paragraphs/ru/ru_0594.txt
# Writing short_paragraphs/ru/ru_0595.txt
# Writing short_paragraphs/ru/ru_0596.txt
# Writing short_paragraphs/ru/ru_0597.txt
# Writing short_paragraphs/ru/ru_0598.txt
# Writing short_paragraphs/ru/ru_0599.txt
# Writing short_paragraphs/ru/ru_0600.txt
# Writing short_paragraphs/ru/ru_0601.txt
# Writing short_paragraphs/ru/ru_0602.txt
# Writing short_paragraphs/ru/ru_0603.txt
# Writing short_paragraphs/ru/ru_0604.txt
# Writing short_paragraphs/ru/ru_0605.txt
# Writing short_paragraphs/ru/ru_0606.txt
# Writing short_paragraphs/ru/ru_0607.txt
# Writing short_paragraphs/ru/ru_0608.txt
# Writing short_paragraphs/ru/ru_0609.txt
# Writing short_paragraphs/ru/ru_0610.txt
# Writing paragraphs/ru/ru_0040.txt
# Writing short_paragraphs/ru/ru_0611.txt
# Writing short_paragraphs/ru/ru_0612.txt
# Writing short_paragraphs/ru/ru_0613.txt
# Writing short_paragraphs/ru/ru_0614.txt
# Writing short_paragraphs/ru/ru_0615.txt
# Writing short_paragraphs/ru/ru_0616.txt
# Writing short_paragraphs/ru/ru_0617.txt
# Writing short_paragraphs/ru/ru_0618.txt
# Writing paragraphs/ru/ru_0041.txt
# Writing short_paragraphs/ru/ru_0619.txt
# Writing short_paragraphs/ru/ru_0620.txt
# Writing short_paragraphs/ru/ru_0621.txt
# Writing short_paragraphs/ru/ru_0622.txt
# Writing short_paragraphs/ru/ru_0623.txt
# Writing short_paragraphs/ru/ru_0624.txt
# Writing short_paragraphs/ru/ru_0625.txt
# Writing short_paragraphs/ru/ru_0626.txt
# Writing short_paragraphs/ru/ru_0627.txt
# Writing short_paragraphs/ru/ru_0628.txt
# Writing short_paragraphs/ru/ru_0629.txt
# Writing short_paragraphs/ru/ru_0630.txt
# Writing short_paragraphs/ru/ru_0631.txt
# Writing short_paragraphs/ru/ru_0632.txt
# Writing short_paragraphs/ru/ru_0633.txt
# Writing short_paragraphs/ru/ru_0634.txt
# Writing short_paragraphs/ru/ru_0635.txt
# Writing paragraphs/ru/ru_0042.txt
# Writing short_paragraphs/ru/ru_0636.txt
# Writing short_paragraphs/ru/ru_0637.txt
# Writing short_paragraphs/ru/ru_0638.txt
# Writing short_paragraphs/ru/ru_0639.txt
# Writing short_paragraphs/ru/ru_0640.txt
# Writing short_paragraphs/ru/ru_0641.txt
# Writing short_paragraphs/ru/ru_0642.txt
# Writing short_paragraphs/ru/ru_0643.txt
# Writing short_paragraphs/ru/ru_0644.txt
# Writing short_paragraphs/ru/ru_0645.txt
# Writing short_paragraphs/ru/ru_0646.txt
# Writing short_paragraphs/ru/ru_0647.txt
# Writing short_paragraphs/ru/ru_0648.txt
# Writing short_paragraphs/ru/ru_0649.txt
# Writing short_paragraphs/ru/ru_0650.txt
# Writing short_paragraphs/ru/ru_0651.txt
# Writing short_paragraphs/ru/ru_0652.txt
# Writing paragraphs/ru/ru_0043.txt
# Writing short_paragraphs/ru/ru_0653.txt
# Writing short_paragraphs/ru/ru_0654.txt
# Writing short_paragraphs/ru/ru_0655.txt
# Writing short_paragraphs/ru/ru_0656.txt
# Writing short_paragraphs/ru/ru_0657.txt
# Writing short_paragraphs/ru/ru_0658.txt
# Writing short_paragraphs/ru/ru_0659.txt
# Writing short_paragraphs/ru/ru_0660.txt
# Writing short_paragraphs/ru/ru_0661.txt
# Writing short_paragraphs/ru/ru_0662.txt
# Writing short_paragraphs/ru/ru_0663.txt
# Writing short_paragraphs/ru/ru_0664.txt
# Writing short_paragraphs/ru/ru_0665.txt
# Writing short_paragraphs/ru/ru_0666.txt
# Writing short_paragraphs/ru/ru_0667.txt
# Writing short_paragraphs/ru/ru_0668.txt
# Writing short_paragraphs/ru/ru_0669.txt
# Writing short_paragraphs/ru/ru_0670.txt
# Writing paragraphs/ru/ru_0044.txt
# Writing short_paragraphs/ru/ru_0671.txt
# Writing short_paragraphs/ru/ru_0672.txt
# Writing short_paragraphs/ru/ru_0673.txt
# Writing short_paragraphs/ru/ru_0674.txt
# Writing short_paragraphs/ru/ru_0675.txt
# Writing short_paragraphs/ru/ru_0676.txt
# Writing short_paragraphs/ru/ru_0677.txt
# Writing short_paragraphs/ru/ru_0678.txt
# Writing paragraphs/ru/ru_0045.txt
# Writing short_paragraphs/ru/ru_0679.txt
# Writing short_paragraphs/ru/ru_0680.txt
# Writing short_paragraphs/ru/ru_0681.txt
# Writing short_paragraphs/ru/ru_0682.txt
# Writing short_paragraphs/ru/ru_0683.txt
# Writing short_paragraphs/ru/ru_0684.txt
# Writing short_paragraphs/ru/ru_0685.txt
# Writing short_paragraphs/ru/ru_0686.txt
# Writing short_paragraphs/ru/ru_0687.txt
# Writing short_paragraphs/ru/ru_0688.txt
# Writing short_paragraphs/ru/ru_0689.txt
# Writing short_paragraphs/ru/ru_0690.txt
# Writing short_paragraphs/ru/ru_0691.txt
# Writing short_paragraphs/ru/ru_0692.txt
# Writing short_paragraphs/ru/ru_0693.txt
# Writing short_paragraphs/ru/ru_0694.txt
# Writing short_paragraphs/ru/ru_0695.txt
# Writing short_paragraphs/ru/ru_0696.txt
# Writing short_paragraphs/ru/ru_0697.txt
# Writing short_paragraphs/ru/ru_0698.txt
# Writing short_paragraphs/ru/ru_0699.txt
# Writing short_paragraphs/ru/ru_0700.txt
# Writing short_paragraphs/ru/ru_0701.txt
# Writing short_paragraphs/ru/ru_0702.txt
# Writing short_paragraphs/ru/ru_0703.txt
# Writing short_paragraphs/ru/ru_0704.txt
# Writing short_paragraphs/ru/ru_0705.txt
# Writing short_paragraphs/ru/ru_0706.txt
# Writing short_paragraphs/ru/ru_0707.txt
# Writing short_paragraphs/ru/ru_0708.txt
# Writing short_paragraphs/ru/ru_0709.txt
# Writing short_paragraphs/ru/ru_0710.txt
# Writing short_paragraphs/ru/ru_0711.txt
# Writing short_paragraphs/ru/ru_0712.txt
# Writing paragraphs/ru/ru_0046.txt
# Writing short_paragraphs/ru/ru_0713.txt
# Writing short_paragraphs/ru/ru_0714.txt
# Writing short_paragraphs/ru/ru_0715.txt
# Writing short_paragraphs/ru/ru_0716.txt
# Writing short_paragraphs/ru/ru_0717.txt
# Writing short_paragraphs/ru/ru_0718.txt
# Writing short_paragraphs/ru/ru_0719.txt
# Writing short_paragraphs/ru/ru_0720.txt
# Writing short_paragraphs/ru/ru_0721.txt
# Writing short_paragraphs/ru/ru_0722.txt
# Writing paragraphs/ru/ru_0047.txt
# Writing short_paragraphs/ru/ru_0723.txt
# Writing short_paragraphs/ru/ru_0724.txt
# Writing short_paragraphs/ru/ru_0725.txt
# Writing short_paragraphs/ru/ru_0726.txt
# Writing short_paragraphs/ru/ru_0727.txt
# Writing short_paragraphs/ru/ru_0728.txt
# Writing short_paragraphs/ru/ru_0729.txt
# Writing short_paragraphs/ru/ru_0730.txt
# Writing short_paragraphs/ru/ru_0731.txt
# Writing short_paragraphs/ru/ru_0732.txt
# Writing short_paragraphs/ru/ru_0733.txt
# Writing short_paragraphs/ru/ru_0734.txt
# Writing short_paragraphs/ru/ru_0735.txt
# Writing short_paragraphs/ru/ru_0736.txt
# Writing paragraphs/ru/ru_0048.txt
# Writing short_paragraphs/ru/ru_0737.txt
# Writing short_paragraphs/ru/ru_0738.txt
# Writing short_paragraphs/ru/ru_0739.txt
# Writing short_paragraphs/ru/ru_0740.txt
# Writing short_paragraphs/ru/ru_0741.txt
# Writing short_paragraphs/ru/ru_0742.txt
# Writing short_paragraphs/ru/ru_0743.txt
# Writing short_paragraphs/ru/ru_0744.txt
# Writing short_paragraphs/ru/ru_0745.txt
# Writing short_paragraphs/ru/ru_0746.txt
# Writing short_paragraphs/ru/ru_0747.txt
# Writing paragraphs/ru/ru_0049.txt
# Writing short_paragraphs/ru/ru_0748.txt
# Writing short_paragraphs/ru/ru_0749.txt
# Writing paragraphs/ru/ru_0050.txt
# Writing short_paragraphs/ru/ru_0750.txt
# Writing short_paragraphs/ru/ru_0751.txt
# Writing short_paragraphs/ru/ru_0752.txt
# Writing short_paragraphs/ru/ru_0753.txt
# Writing short_paragraphs/ru/ru_0754.txt
# Writing short_paragraphs/ru/ru_0755.txt
# Writing short_paragraphs/ru/ru_0756.txt
# Writing short_paragraphs/ru/ru_0757.txt
# Writing short_paragraphs/ru/ru_0758.txt
# Writing paragraphs/ru/ru_0051.txt
# Writing short_paragraphs/ru/ru_0759.txt
# Writing short_paragraphs/ru/ru_0760.txt
# Writing short_paragraphs/ru/ru_0761.txt
# Writing short_paragraphs/ru/ru_0762.txt
# Writing short_paragraphs/ru/ru_0763.txt
# Writing short_paragraphs/ru/ru_0764.txt
# Writing short_paragraphs/ru/ru_0765.txt
# Writing short_paragraphs/ru/ru_0766.txt
# Writing short_paragraphs/ru/ru_0767.txt
# Writing short_paragraphs/ru/ru_0768.txt
# Writing short_paragraphs/ru/ru_0769.txt
# Writing short_paragraphs/ru/ru_0770.txt
# Writing short_paragraphs/ru/ru_0771.txt
# Writing short_paragraphs/ru/ru_0772.txt
# Writing short_paragraphs/ru/ru_0773.txt
# Writing short_paragraphs/ru/ru_0774.txt
# Writing short_paragraphs/ru/ru_0775.txt
# Writing short_paragraphs/ru/ru_0776.txt
# Writing short_paragraphs/ru/ru_0777.txt
# Writing short_paragraphs/ru/ru_0778.txt
# Writing short_paragraphs/ru/ru_0779.txt
# Writing short_paragraphs/ru/ru_0780.txt
# Writing short_paragraphs/ru/ru_0781.txt
# Writing short_paragraphs/ru/ru_0782.txt
# Writing paragraphs/ru/ru_0052.txt
# Writing short_paragraphs/ru/ru_0783.txt
# Writing short_paragraphs/ru/ru_0784.txt
# Writing short_paragraphs/ru/ru_0785.txt
# Writing short_paragraphs/ru/ru_0786.txt
# Writing short_paragraphs/ru/ru_0787.txt
# Writing short_paragraphs/ru/ru_0788.txt
# Writing short_paragraphs/ru/ru_0789.txt
# Writing short_paragraphs/ru/ru_0790.txt
# Writing short_paragraphs/ru/ru_0791.txt
# Writing short_paragraphs/ru/ru_0792.txt
# Writing short_paragraphs/ru/ru_0793.txt
# Writing short_paragraphs/ru/ru_0794.txt
# Writing short_paragraphs/ru/ru_0795.txt
# Writing short_paragraphs/ru/ru_0796.txt
# Writing short_paragraphs/ru/ru_0797.txt
# Writing short_paragraphs/ru/ru_0798.txt
# Writing short_paragraphs/ru/ru_0799.txt
# Writing short_paragraphs/ru/ru_0800.txt
# Writing short_paragraphs/ru/ru_0801.txt
# Writing short_paragraphs/ru/ru_0802.txt
# Writing short_paragraphs/ru/ru_0803.txt
# Writing short_paragraphs/ru/ru_0804.txt
# Writing paragraphs/ru/ru_0053.txt
# Writing short_paragraphs/ru/ru_0805.txt
# Writing short_paragraphs/ru/ru_0806.txt
# Writing short_paragraphs/ru/ru_0807.txt
# Writing short_paragraphs/ru/ru_0808.txt
# Writing short_paragraphs/ru/ru_0809.txt
# Writing short_paragraphs/ru/ru_0810.txt
# Writing short_paragraphs/ru/ru_0811.txt
# Writing short_paragraphs/ru/ru_0812.txt
# Writing short_paragraphs/ru/ru_0813.txt
# Writing short_paragraphs/ru/ru_0814.txt
# Writing short_paragraphs/ru/ru_0815.txt
# Writing short_paragraphs/ru/ru_0816.txt
# Writing short_paragraphs/ru/ru_0817.txt
# Writing short_paragraphs/ru/ru_0818.txt
# Writing short_paragraphs/ru/ru_0819.txt
# Writing short_paragraphs/ru/ru_0820.txt
# Writing short_paragraphs/ru/ru_0821.txt
# Writing short_paragraphs/ru/ru_0822.txt
# Writing short_paragraphs/ru/ru_0823.txt
# Writing short_paragraphs/ru/ru_0824.txt
# Writing short_paragraphs/ru/ru_0825.txt
# Writing short_paragraphs/ru/ru_0826.txt
# Writing short_paragraphs/ru/ru_0827.txt
# Writing short_paragraphs/ru/ru_0828.txt
# Writing paragraphs/ru/ru_0054.txt
# Writing short_paragraphs/ru/ru_0829.txt
# Writing short_paragraphs/ru/ru_0830.txt
# Writing short_paragraphs/ru/ru_0831.txt
# Writing short_paragraphs/ru/ru_0832.txt
# Writing short_paragraphs/ru/ru_0833.txt
# Writing short_paragraphs/ru/ru_0834.txt
# Writing short_paragraphs/ru/ru_0835.txt
# Writing short_paragraphs/ru/ru_0836.txt
# Writing short_paragraphs/ru/ru_0837.txt
# Writing short_paragraphs/ru/ru_0838.txt
# Writing short_paragraphs/ru/ru_0839.txt
# Writing short_paragraphs/ru/ru_0840.txt
# Writing short_paragraphs/ru/ru_0841.txt
# Writing paragraphs/ru/ru_0055.txt
# Writing short_paragraphs/ru/ru_0842.txt
# Writing short_paragraphs/ru/ru_0843.txt
# Writing short_paragraphs/ru/ru_0844.txt
# Writing short_paragraphs/ru/ru_0845.txt
# Writing short_paragraphs/ru/ru_0846.txt
# Writing short_paragraphs/ru/ru_0847.txt
# Writing short_paragraphs/ru/ru_0848.txt
# Writing short_paragraphs/ru/ru_0849.txt
# Writing short_paragraphs/ru/ru_0850.txt
# Writing short_paragraphs/ru/ru_0851.txt
# Writing short_paragraphs/ru/ru_0852.txt
# Writing short_paragraphs/ru/ru_0853.txt
# Writing short_paragraphs/ru/ru_0854.txt
# Writing short_paragraphs/ru/ru_0855.txt
# Writing short_paragraphs/ru/ru_0856.txt
# Writing short_paragraphs/ru/ru_0857.txt
# Writing short_paragraphs/ru/ru_0858.txt
# Writing short_paragraphs/ru/ru_0859.txt
# Writing short_paragraphs/ru/ru_0860.txt
# Writing paragraphs/ru/ru_0056.txt
# Writing short_paragraphs/ru/ru_0861.txt
# Writing short_paragraphs/ru/ru_0862.txt
# Writing short_paragraphs/ru/ru_0863.txt
# Writing paragraphs/ru/ru_0057.txt
# Writing short_paragraphs/ru/ru_0864.txt
# Writing short_paragraphs/ru/ru_0865.txt
# Writing short_paragraphs/ru/ru_0866.txt
# Writing short_paragraphs/ru/ru_0867.txt
# Writing short_paragraphs/ru/ru_0868.txt
# Writing short_paragraphs/ru/ru_0869.txt
# Writing short_paragraphs/ru/ru_0870.txt
# Writing short_paragraphs/ru/ru_0871.txt
# Writing short_paragraphs/ru/ru_0872.txt
# Writing short_paragraphs/ru/ru_0873.txt
# Writing short_paragraphs/ru/ru_0874.txt
# Writing short_paragraphs/ru/ru_0875.txt
# Writing short_paragraphs/ru/ru_0876.txt
# Writing short_paragraphs/ru/ru_0877.txt
# Writing short_paragraphs/ru/ru_0878.txt
# Writing short_paragraphs/ru/ru_0879.txt
# Writing short_paragraphs/ru/ru_0880.txt
# Writing short_paragraphs/ru/ru_0881.txt
# Writing short_paragraphs/ru/ru_0882.txt
# Writing short_paragraphs/ru/ru_0883.txt
# Writing short_paragraphs/ru/ru_0884.txt
# Writing short_paragraphs/ru/ru_0885.txt
# Writing short_paragraphs/ru/ru_0886.txt
# Writing short_paragraphs/ru/ru_0887.txt
# Writing short_paragraphs/ru/ru_0888.txt
# Writing short_paragraphs/ru/ru_0889.txt
# Writing short_paragraphs/ru/ru_0890.txt
# Writing short_paragraphs/ru/ru_0891.txt
# Writing paragraphs/ru/ru_0058.txt
# Writing short_paragraphs/ru/ru_0892.txt
# Writing short_paragraphs/ru/ru_0893.txt
# Writing short_paragraphs/ru/ru_0894.txt
# Writing short_paragraphs/ru/ru_0895.txt
# Writing short_paragraphs/ru/ru_0896.txt
# Writing short_paragraphs/ru/ru_0897.txt
# Writing short_paragraphs/ru/ru_0898.txt
# Writing short_paragraphs/ru/ru_0899.txt
# Writing short_paragraphs/ru/ru_0900.txt
# Writing short_paragraphs/ru/ru_0901.txt
# Writing short_paragraphs/ru/ru_0902.txt
# Writing short_paragraphs/ru/ru_0903.txt
# Writing short_paragraphs/ru/ru_0904.txt
# Writing short_paragraphs/ru/ru_0905.txt
# Writing short_paragraphs/ru/ru_0906.txt
# Writing short_paragraphs/ru/ru_0907.txt
# Writing short_paragraphs/ru/ru_0908.txt
# Writing short_paragraphs/ru/ru_0909.txt
# Writing short_paragraphs/ru/ru_0910.txt
# Writing short_paragraphs/ru/ru_0911.txt
# Writing paragraphs/ru/ru_0059.txt
# Writing short_paragraphs/ru/ru_0912.txt
# Writing short_paragraphs/ru/ru_0913.txt
# Writing short_paragraphs/ru/ru_0914.txt
# Writing short_paragraphs/ru/ru_0915.txt
# Writing short_paragraphs/ru/ru_0916.txt
# Writing short_paragraphs/ru/ru_0917.txt
# Writing paragraphs/ru/ru_0060.txt
# Writing short_paragraphs/ru/ru_0918.txt
# Writing short_paragraphs/ru/ru_0919.txt
# Writing short_paragraphs/ru/ru_0920.txt
# Writing short_paragraphs/ru/ru_0921.txt
# Writing short_paragraphs/ru/ru_0922.txt
# Writing paragraphs/ru/ru_0061.txt
# Writing short_paragraphs/ru/ru_0923.txt
# Writing short_paragraphs/ru/ru_0924.txt
# Writing short_paragraphs/ru/ru_0925.txt
# Writing short_paragraphs/ru/ru_0926.txt
# Writing short_paragraphs/ru/ru_0927.txt
# Writing paragraphs/ru/ru_0062.txt
# Writing short_paragraphs/ru/ru_0928.txt
# Writing short_paragraphs/ru/ru_0929.txt
# Writing short_paragraphs/ru/ru_0930.txt
# Writing short_paragraphs/ru/ru_0931.txt
# Writing short_paragraphs/ru/ru_0932.txt
# Writing short_paragraphs/ru/ru_0933.txt
# Writing short_paragraphs/ru/ru_0934.txt
# Writing paragraphs/ru/ru_0063.txt
# Writing short_paragraphs/ru/ru_0935.txt
# Writing short_paragraphs/ru/ru_0936.txt
# Writing short_paragraphs/ru/ru_0937.txt
# Writing short_paragraphs/ru/ru_0938.txt
# Writing short_paragraphs/ru/ru_0939.txt
# Writing short_paragraphs/ru/ru_0940.txt
# Writing short_paragraphs/ru/ru_0941.txt
# Writing short_paragraphs/ru/ru_0942.txt
# Writing short_paragraphs/ru/ru_0943.txt
# Writing short_paragraphs/ru/ru_0944.txt
# Writing short_paragraphs/ru/ru_0945.txt
# Writing paragraphs/ru/ru_0064.txt
# Writing short_paragraphs/ru/ru_0946.txt
# Writing short_paragraphs/ru/ru_0947.txt
# Writing short_paragraphs/ru/ru_0948.txt
# Writing short_paragraphs/ru/ru_0949.txt
# Writing short_paragraphs/ru/ru_0950.txt
# Writing short_paragraphs/ru/ru_0951.txt
# Writing paragraphs/ru/ru_0065.txt
# Writing short_paragraphs/ru/ru_0952.txt
# Writing short_paragraphs/ru/ru_0953.txt
# Writing short_paragraphs/ru/ru_0954.txt
# Writing short_paragraphs/ru/ru_0955.txt
# Writing short_paragraphs/ru/ru_0956.txt
# Writing short_paragraphs/ru/ru_0957.txt
# Writing short_paragraphs/ru/ru_0958.txt
# Writing short_paragraphs/ru/ru_0959.txt
# Writing short_paragraphs/ru/ru_0960.txt
# Writing paragraphs/ru/ru_0066.txt
# Writing short_paragraphs/ru/ru_0961.txt
# Writing short_paragraphs/ru/ru_0962.txt
# Writing short_paragraphs/ru/ru_0963.txt

# %%
"""Script to download the movie review dataset"""

from pathlib import Path
from hashlib import sha256
import tarfile
from urllib.request import urlopen


URL = "http://www.cs.cornell.edu/people/pabo/movie-review-data/review_polarity.tar.gz"

ARCHIVE_SHA256 = "fc0dccc2671af5db3c5d8f81f77a1ebfec953ecdd422334062df61ede36b2179"
ARCHIVE_NAME = Path(URL.rsplit("/", 1)[1])
DATA_FOLDER = Path("txt_sentoken")


if not DATA_FOLDER.exists():

    if not ARCHIVE_NAME.exists():
        print("Downloading dataset from %s (3 MB)" % URL)
        opener = urlopen(URL)
        with open(ARCHIVE_NAME, "wb") as archive:
            archive.write(opener.read())

    try:
        print("Checking the integrity of the archive")
        assert sha256(ARCHIVE_NAME.read_bytes()).hexdigest() == ARCHIVE_SHA256

        print("Decompressing %s" % ARCHIVE_NAME)
        with tarfile.open(ARCHIVE_NAME, "r:gz") as archive:
            archive.extractall(path=".")

    finally:
        ARCHIVE_NAME.unlink()
# Out:
# Downloading dataset from http://www.cs.cornell.edu/people/pabo/movie-review-data/review_polarity.tar.gz (3 MB)
# Checking the integrity of the archive
# Decompressing review_polarity.tar.gz

# %%
from sklearn.datasets import fetch_20newsgroups
categories = ['alt.atheism', 'soc.religion.christian',
              'comp.graphics', 'sci.med']
twenty_train = fetch_20newsgroups(subset='train',
     categories=categories, shuffle=True, random_state=42)

# %%
twenty_train.target_names
# Out:
# ['alt.atheism', 'comp.graphics', 'sci.med', 'soc.religion.christian']

# %%
len(twenty_train.data)
# Out:
# 2257

# %%
len(twenty_train.filenames)
# Out:
# 2257

# %%
print("\n".join(twenty_train.data[0].split("\n")[:3]))
# Out:
# From: sd345@city.ac.uk (Michael Collier)
# Subject: Converting images to HP LaserJet III?
# Nntp-Posting-Host: hampton

# %%
print(twenty_train.target_names[twenty_train.target[0]])
# Out:
# comp.graphics

# %%
twenty_train.target[:10]
# Out:
# array([1, 1, 3, 3, 3, 3, 3, 2, 2, 2])

# %%
for t in twenty_train.target[:10]:
    print(twenty_train.target_names[t])
# Out:
# comp.graphics
# comp.graphics
# soc.religion.christian
# soc.religion.christian
# soc.religion.christian
# soc.religion.christian
# soc.religion.christian
# sci.med
# sci.med
# sci.med

# %% [markdown]
# ## Extracting features from text files

# %%
from sklearn.feature_extraction.text import CountVectorizer
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(twenty_train.data)
X_train_counts.shape
# Out:
# (2257, 35788)

# %%
count_vect.vocabulary_.get(u'algorithm')
# Out:
# 4690

# %%
from sklearn.feature_extraction.text import TfidfTransformer
tf_transformer = TfidfTransformer(use_idf=False).fit(X_train_counts)
X_train_tf = tf_transformer.transform(X_train_counts)
X_train_tf.shape
# Out:
# (2257, 35788)

# %%
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
X_train_tfidf.shape
# Out:
# (2257, 35788)

# %% [markdown]
# ## Training a classifier

# %%
from sklearn.naive_bayes import MultinomialNB
clf = MultinomialNB().fit(X_train_tfidf, twenty_train.target)

# %%
docs_new = ['God is love', 'OpenGL on the GPU is fast']
X_new_counts = count_vect.transform(docs_new)
X_new_tfidf = tfidf_transformer.transform(X_new_counts)

predicted = clf.predict(X_new_tfidf)

for doc, category in zip(docs_new, predicted):
    print('%r => %s' % (doc, twenty_train.target_names[category]))
# Out:
# 'God is love' => soc.religion.christian
# 'OpenGL on the GPU is fast' => comp.graphics

# %% [markdown]
# ## Building a pipeline

# %%
from sklearn.pipeline import Pipeline
text_clf = Pipeline([
    ('vect', CountVectorizer()),
    ('tfidf', TfidfTransformer()),
    ('clf', MultinomialNB()),
])

# %%
text_clf.fit(twenty_train.data, twenty_train.target)
# Out:
# Pipeline(steps=[('vect', CountVectorizer()), ('tfidf', TfidfTransformer()),
#                 ('clf', MultinomialNB())])

# %% [markdown]
# ## Evaluation of the performance on the test set

# %%
import numpy as np
twenty_test = fetch_20newsgroups(subset='test',
    categories=categories, shuffle=True, random_state=42)
docs_test = twenty_test.data
predicted = text_clf.predict(docs_test)
np.mean(predicted == twenty_test.target)
# Out:
# 0.8348868175765646

# %%
from sklearn.linear_model import SGDClassifier
text_clf = Pipeline([
    ('vect', CountVectorizer()),
    ('tfidf', TfidfTransformer()),
    ('clf', SGDClassifier(loss='hinge', penalty='l2',
                          alpha=1e-3, random_state=42,
                          max_iter=5, tol=None)),
])

text_clf.fit(twenty_train.data, twenty_train.target)

predicted = text_clf.predict(docs_test)
np.mean(predicted == twenty_test.target)
# Out:
# 0.9101198402130493

# %%
from sklearn import metrics
print(metrics.classification_report(twenty_test.target, predicted,
    target_names=twenty_test.target_names))

metrics.confusion_matrix(twenty_test.target, predicted)
# Out:
#                         precision    recall  f1-score   support
#
#            alt.atheism       0.95      0.80      0.87       319
#          comp.graphics       0.87      0.98      0.92       389
#                sci.med       0.94      0.89      0.91       396
# soc.religion.christian       0.90      0.95      0.93       398
#
#               accuracy                           0.91      1502
#              macro avg       0.91      0.91      0.91      1502
#           weighted avg       0.91      0.91      0.91      1502
# array([[256,  11,  16,  36],
#        [  4, 380,   3,   2],
#        [  5,  35, 353,   3],
#        [  5,  11,   4, 378]])

# %% [markdown]
# ## Parameter tuning using grid search

# %%
from sklearn.model_selection import GridSearchCV
parameters = {
    'vect__ngram_range': [(1, 1), (1, 2)],
    'tfidf__use_idf': (True, False),
    'clf__alpha': (1e-2, 1e-3),
}

# %%
gs_clf = GridSearchCV(text_clf, parameters, cv=5, n_jobs=-1)

# %%
gs_clf = gs_clf.fit(twenty_train.data[:400], twenty_train.target[:400])

# %%
twenty_train.target_names[gs_clf.predict(['God is love'])[0]]
# Out:
# 'soc.religion.christian'

# %%
gs_clf.best_score_

for param_name in sorted(parameters.keys()):
    print("%s: %r" % (param_name, gs_clf.best_params_[param_name]))
# Out:
# clf__alpha: 0.001
# tfidf__use_idf: True
# vect__ngram_range: (1, 1)
